# %%
import pandas as pd
from pandas import DataFrame
import numpy as np  
from pandas import Series

# %%
#《No.1 military medical project》table 4.1 DIAGNOSIS_DICT 
DIAGNOSIS_DICT = pd.read_csv('F:/data/input/DIAGNOSIS_DICT.tsv', sep='\t')

# %%
print(DIAGNOSIS_DICT)
# Out:
#          DIAGNOSIS_CODE DIAGNOSIS_NAME  STD_INDICATOR  APPROVED_INDICATOR  \
# 0               Z99.201   肾脏透析(CAPD)状态              1                   1
# 1               Z99.101        依赖于呼吸器者              1                   1
# 2               Z98.881       皮肤恶性肿瘤术后              1                   1
# 3               Z98.880         心肺复苏术后              1                   1
# 4               Z98.879          鼻整形术后              1                   1
# 5               Z98.878        头面部肿瘤术后              1                   1
# 6               Z98.877           吸脂术后              1                   1
# 7               Z98.875        肾结石碎石术后              1                   1
# 8               Z98.874        脊柱内固定术后              1                   1
# 9               Z98.873    支气管动脉栓塞治疗术后              1                   1
# 10              Z98.872         阑尾切除术后              1                   1
# 11              Z98.871       胸腔肿瘤切除术后              1                   1
# ...

# %%
# 《No.1 military medical project》9.1 表 病人主索引  PAT_MASTER_INDEX 预处理后

PAT_MASTER_INDEX = pd.read_csv('F:/data/input/病人主索引_预.tsv', sep='\t')

# %%
print(PAT_MASTER_INDEX)
# Out:
#         PATIENT_ID SEX DATE_OF_BIRTH
# 0         04001738   女     01-1月 -46
# 1         04001739   男     01-1月 -30
# 2         04001740   女     01-1月 -60
# 3         04001795   女     01-1月 -69
# 4         04001741   男     01-1月 -40
# 5         04001796   女     01-1月 -69
# 6         07000902   男     01-1月 -48
# 7         04001291   男     01-1月 -30
# 8         09000490   男     01-7月 -65
# 9         04001101   女     01-1月 -64
# 10        04001614   男     01-1月 -36
# 11        04001742   男     01-1月 -54
# 12        04001750   女     01-1月 -50
# 13        06001088   女     24-8月 -55
# 14        04001743   男     01-1月 -41
# 15        04001799   男     01-1月 -64
# 16        07000876   男     01-1月 -62
# 17        04001751   女     02-9月 -56
# 18        07001055   男     01-1月 -67
# 19        08000278   男     01-4月 -26
# 20        07001392   男     16-11月-64
# 21        04003913   女     01-1月 -80
# 22        04003912   男     01-1月 -70
# 23        04003911   男     01-1月 -74
# ...

# %%
# 表9.7测试
DIAGNOSTIC_CATEGORY = pd.read_csv('F:/data/input/诊断分类记录_全.tsv', sep='\t',nrows =500)

# %%
print(DIAGNOSTIC_CATEGORY)
# Out:
#      PATIENT_ID  VISIT_ID  DIAGNOSIS_TYPE  DIAGNOSIS_NO    DIAGNOSIS_CODE  \
# 0       4003500         2               2             1           261  01
# 1       4003500         2               3             1           307.101
# 2       4003500         2               3             2           273.801
# 3       4003500         2               3             3           280  01
# 4       4010720         1               5             1           799.402
# 5       4010720         1               6             1           567.905
# 6       4007153         1               1             1  070.901+573.106*
# 7       4007153         1               2             1  070.901+573.106*
# 8       4007153         1               3             1           155.201
# 9       4017543         1               1             1           162.901
# 10      4017543         1               2             1           793.101
# 11      4017543         1               3             1           793.101
# ...

# %%
#表9.7 诊断分类记录 DIAGNOSTIC_CATEGORY 预处理
DIAGNOSTIC_CATEGORY = pd.read_csv('F:/data/input/诊断分类记录.tsv', sep='\t')

# %%
print(DIAGNOSTIC_CATEGORY)
# Out:
#         PATIENT_ID DIAGNOSIS_CODE
# 0                `        E79.001
# 1                `        I50.910
# 2                `        I11.901
# 3                `        I10  06
# 4                `        I11.901
# 5                `        I10  06
# 6                `        I10  03
# 7                ]        S90.301
# 8                ]        W20.902
# 9                ]        S92.511
# 10               ]        S92.511
# 11               ]        S92.511
# 12         Z98.850        Z98.850
# 13         Z98.850        Q24.911
# 14         Z98.850        Z98.850
# 15         Z98.850        Q24.911
# 16         Z98.850        Q24.911
# 17         Z98.830        Z98.830
# 18         Z98.830        Z98.830
# 19         Z98.830        C16.901
# 20         Z98.829        C78.201
# 21         Z98.829        Z98.829
# 22         Z98.829       M80100/3
# 23         Z98.829        I84.201
# 24         Z98.829        I84.201
# 25         Z98.829        Z98.829
# ...

# %%
DIAGNOSTIC_CATEGORY
# Out:
#         PATIENT_ID DIAGNOSIS_CODE
# 0                `        E79.001
# 1                `        I50.910
# 2                `        I11.901
# 3                `        I10  06
# 4                `        I11.901
# 5                `        I10  06
# 6                `        I10  03
# 7                ]        S90.301
# 8                ]        W20.902
# 9                ]        S92.511
# 10               ]        S92.511
# 11               ]        S92.511
# 12         Z98.850        Z98.850
# 13         Z98.850        Q24.911
# 14         Z98.850        Z98.850
# 15         Z98.850        Q24.911
# 16         Z98.850        Q24.911
# 17         Z98.830        Z98.830
# 18         Z98.830        Z98.830
# 19         Z98.830        C16.901
# 20         Z98.829        C78.201
# 21         Z98.829        Z98.829
# 22         Z98.829       M80100/3
# 23         Z98.829        I84.201
# 24         Z98.829        I84.201
# 25         Z98.829        Z98.829
# ...

# %%
DIAGNOSTIC_CATEGORY_1=pd.read_csv('F:/data/input/诊断分类记录.tsv', sep='\t',usecols=[1])

# %%
print(DIAGNOSTIC_CATEGORY_1['DIAGNOSIS_CODE'])
# Out:
# 0           E79.001
# 1           I50.910
# 2           I11.901
# 3           I10  06
# 4           I11.901
# 5           I10  06
# 6           I10  03
# 7           S90.301
# 8           W20.902
# 9           S92.511
# 10          S92.511
# 11          S92.511
# 12          Z98.850
# 13          Q24.911
# 14          Z98.850
# 15          Q24.911
# 16          Q24.911
# 17          Z98.830
# 18          Z98.830
# 19          C16.901
# 20          C78.201
# 21          Z98.829
# 22         M80100/3
# 23          I84.201
# 24          I84.201
# 25          Z98.829
# 26          W50.302
# 27          S42.001
# 28          S42.001
# 29          S42.001
#              ...
# 1180013     J96.901
# 1180014     J98.403
# 1180015     J98.403
# 1180016     J42  03
# 1180017     J42  03
# 1180018     H91.201
# 1180019     H91.201
# 1180020     H91.201
# 1180021     O69.101
# 1180022     Z37.001
# 1180023     O63.101
# 1180024     O80.901
# 1180025     O47.101
# 1180026     O47.101
# ...

# %%
DIAGNOSTIC_CATEGORY_1
# Out:
#         DIAGNOSIS_CODE
# 0              E79.001
# 1              I50.910
# 2              I11.901
# 3              I10  06
# 4              I11.901
# 5              I10  06
# 6              I10  03
# 7              S90.301
# 8              W20.902
# 9              S92.511
# 10             S92.511
# 11             S92.511
# 12             Z98.850
# 13             Q24.911
# 14             Z98.850
# 15             Q24.911
# 16             Q24.911
# 17             Z98.830
# 18             Z98.830
# 19             C16.901
# 20             C78.201
# 21             Z98.829
# 22            M80100/3
# 23             I84.201
# 24             I84.201
# 25             Z98.829
# 26             W50.302
# 27             S42.001
# 28             S42.001
# 29             S42.001
# ...                ...
# 1180013        J96.901
# 1180014        J98.403
# 1180015        J98.403
# 1180016        J42  03
# 1180017        J42  03
# 1180018        H91.201
# 1180019        H91.201
# 1180020        H91.201
# ...

# %%
#统计疾病频率
DIAGNOSTIC_CATEGORY_1['DIAGNOSIS_CODE'].value_counts()
# Out:
# E11.901             36906
# I10  06             24623
# I10  03             24603
# I25.101             24183
# I63.901             20337
# J98.403             14761
# Z98.819             10140
# I10  05              9286
# Z34.801              9236
# X59.903              9097
# Z38.001              8801
# D64.902              8467
# S69.903              8410
# 414.001              8183
# E11.504              7965
# C34.901              7664
# I69.301              7539
# S68.101              7189
# 401.903              6988
# J18.901              6677
# K29.502              6536
# E14.901              6408
# S66.902              6163
# M51.201              5797
# 401.907              5563
# W31.904              5422
# Z37.001              5396
# E77.801              5391
# N40  01              5381
# 465.901              5338
#                     ...
# E900.101                1
# N01.702                 1
# N01.901                 1
# S01.103                 1
# ...

# %%
alist=['E11.901']
DIAGNOSTIC_CATEGORY[DIAGNOSTIC_CATEGORY['DIAGNOSIS_CODE'].isin(alist)]
# Out:
#         PATIENT_ID DIAGNOSIS_CODE
# 136       90223593        E11.901
# 138       90223593        E11.901
# 139       90223593        E11.901
# 147       90220573        E11.901
# 149       90220573        E11.901
# 150       90220573        E11.901
# 153       90220533        E11.901
# 157       90220533        E11.901
# 163       90219173        E11.901
# 166       90219173        E11.901
# 167       90219173        E11.901
# 173       90218013        E11.901
# 176       90218013        E11.901
# 182       90215313        E11.901
# 184       90215313        E11.901
# 188       90214293        E11.901
# 190       90214293        E11.901
# 194       90214293        E11.901
# 196       90214293        E11.901
# 197       90214293        E11.901
# 201       90214253        E11.901
# 206       90214253        E11.901
# 212       90213973        E11.901
# 214       90213973        E11.901
# 216       90213973        E11.901
# 229       90213893        E11.901
# ...

# %%
# 经检验 需要全部字段 此处重做
DIAGNOSTIC_CATEGORY = pd.read_csv('F:/data/input/诊断分类记录_全.tsv', sep='\t')
# Out:
# d:\programdata\anaconda3\envs\tensorflow\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (0,2) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
print(DIAGNOSTIC_CATEGORY)
# Out:
#         PATIENT_ID  VISIT_ID DIAGNOSIS_TYPE  DIAGNOSIS_NO    DIAGNOSIS_CODE  \
# 0         04003500         2              2             1           261  01
# 1         04003500         2              3             1           307.101
# 2         04003500         2              3             2           273.801
# 3         04003500         2              3             3           280  01
# 4         04010720         1              5             1           799.402
# 5         04010720         1              6             1           567.905
# 6         04007153         1              1             1  070.901+573.106*
# 7         04007153         1              2             1  070.901+573.106*
# 8         04007153         1              3             1           155.201
# 9         04017543         1              1             1           162.901
# 10        04017543         1              2             1           793.101
# ...

# %%
alist=['E11.901']
DIAGNOSTIC_CATEGORY[DIAGNOSTIC_CATEGORY['DIAGNOSIS_CODE'].isin(alist)]
# Out:
#         PATIENT_ID  VISIT_ID DIAGNOSIS_TYPE  DIAGNOSIS_NO DIAGNOSIS_CODE  \
# 241068    04051561        10              3             1        E11.901
# 241072    04454003         1              1             1        E11.901
# 241073    04454003         1              2             1        E11.901
# 241074    04454003         1              3             1        E11.901
# 241078    04418940         2              1             1        E11.901
# 241079    04418940         2              2             1        E11.901
# 241080    04418940         2              3             1        E11.901
# 241084    04415618         2              2             1        E11.901
# 241085    04415618         2              3             1        E11.901
# 241170    04272961         2              A             6        E11.901
# 241222    04222659         4              A             3        E11.901
# 241280    04222659         4              2             4        E11.901
# ...

# %%
#筛选出9.7表格中实际人数 125471人
DF = DIAGNOSTIC_CATEGORY['PATIENT_ID'].unique()
SS = Series(DF)
SS
# Out:
# 0         04003500
# 1         04010720
# 2         04007153
# 3         04017543
# 4         04009395
# 5         04004782
# 6         04012439
# 7         04013646
# 8         07000621
# 9         04004925
# 10        04014481
# 11        04003412
# 12        05000095
# 13        04014525
# 14        04013368
# 15        04013778
# 16        04012374
# 17        04001767
# 18        04088927
# 19        04007825
# 20        08000115
# 21        08000019
# 22        04011033
# 23        08000656
# 24        06000557
# 25        04011321
# 26        04007156
# 27        04017493
# 28        08000329
# 29        04016037
#             ...
# 125441     7099892
# 125442     4664565
# 125443     4044958
# 125444     4973170
# 125445     8000377
# 125446     4725154
# 125447     4893539
# 125448     8000278
# 125449     4502694
# 125450     7073968
# 125451     4394714
# 125452     4946613
# 125453     4954524
# 125454     4379012
# 125455     4954139
# 125456     4952242
# ...

# %%
#重定义
test = DIAGNOSTIC_CATEGORY[DIAGNOSTIC_CATEGORY['DIAGNOSIS_CODE'].isin(alist)]
print(test)
# Out:
#         PATIENT_ID  VISIT_ID DIAGNOSIS_TYPE  DIAGNOSIS_NO DIAGNOSIS_CODE  \
# 241068    04051561        10              3             1        E11.901
# 241072    04454003         1              1             1        E11.901
# 241073    04454003         1              2             1        E11.901
# 241074    04454003         1              3             1        E11.901
# 241078    04418940         2              1             1        E11.901
# 241079    04418940         2              2             1        E11.901
# 241080    04418940         2              3             1        E11.901
# 241084    04415618         2              2             1        E11.901
# 241085    04415618         2              3             1        E11.901
# 241170    04272961         2              A             6        E11.901
# 241222    04222659         4              A             3        E11.901
# 241280    04222659         4              2             4        E11.901
# ...

# %%
#筛选出频率第一疾病的实际患病人数 9130人
DF = test['PATIENT_ID'].unique()   
#转格式
SS = Series(DF)
SS
# Out:
# 0       04051561
# 1       04454003
# 2       04418940
# 3       04415618
# 4       04272961
# 5       04222659
# 6       04052182
# 7       04344966
# 8       04043054
# 9       04446737
# 10      04449557
# 11      04453304
# 12      04202608
# 13      04457841
# 14      04221316
# 15      04123900
# 16      04453426
# 17      04451323
# 18      04127891
# 19      04458673
# 20      04180189
# 21      04457360
# 22      04341371
# 23      04327447
# 24      04460206
# 25      04175271
# 26      04460443
# 27      04002377
# 28      04085091
# 29      04095165
#           ...
# 9100    04751774
# 9101    04995790
# 9102    04998425
# 9103    04963808
# 9104    06001333
# 9105    90210513
# 9106    04051656
# 9107    90180893
# 9108    04081744
# 9109    04977411
# 9110    90220533
# 9111    02000299
# 9112    02000095
# 9113    04945297
# 9114    04499975
# 9115    04525478
# 9116    04883819
# 9117    04379700
# 9118    04997176
# 9119     4030598
# 9120     4944210
# ...

# %%
#病人ID
DF
# Out:
# array(['04051561', '04454003', '04418940', ..., 4946613, 4043054, 4802412],
#       dtype=object)

# %%
# 9.1 表 病人主索引  PAT_MASTER_INDEX 预处理后

PAT_MASTER_INDEX = pd.read_csv('F:/data/input/病人主索引_预.tsv', sep='\t')

# %%
# 输出9.1表中患有E11.901 疾病的人的信息（病人ID、性别、年龄）
PAT_MASTER_INDEX[PAT_MASTER_INDEX['PATIENT_ID'].isin(DF)]
# Out:
#         PATIENT_ID SEX DATE_OF_BIRTH
# 77        08000195   男     01-3月 -29
# 273       08000570   男     02-11月-25
# 413       08000596   男     01-10月-29
# 546       04000217   男     01-1月 -22
# 587       04002544   男     16-12月-30
# 836       08000471   男     01-3月 -26
# 838       04005039   女     01-1月 -31
# 845       04005035   女     01-6月 -30
# 1009      08000212   女     01-10月-23
# 1023      04000469   男     01-11月-53
# 1099      07027413   女     01-9月 -63
# 1144      04001204   男     01-1月 -46
# 1206      06001077   男     17-7月 -53
# 1337      04002425   男     01-1月 -48
# 1449      04002874   男     22-2月 -48
# 1485      04008700   女     08-3月 -33
# 1513      06000161   女     16-6月 -35
# 1520      08000152   男     01-5月 -22
# 1524      08000199   男     01-10月-24
# 1599      08000221   男     01-7月 -28
# 1654      06000797   女     30-6月 -28
# 1729      04001735   男     15-3月 -25
# 1851      06002999   女     14-1月 -58
# 1891      04004690   男     21-12月-37
# ...

# %%
#男女比例统计
sex_count = PAT_MASTER_INDEX[PAT_MASTER_INDEX['PATIENT_ID'].isin(DF)]
sex_count['SEX'].value_counts()
# Out:
# 男    5400
# 女    3718
# Name: SEX, dtype: int64

# %%
output_sex = PAT_MASTER_INDEX[PAT_MASTER_INDEX['PATIENT_ID'].isin(DF)]

# %%
#输出疾病1信息
output_sex.to_csv("F:/data/output/疾病1信息.tsv")

# %%
# 9.4 表 诊断记录  预处理后
PAT_DATA = pd.read_csv('F:/data/input/就诊日期.tsv', sep='\t')

# %%
PAT_DATA
# Out:
#         PATIENT_ID DIAGNOSIS_DATE
# 0         08000598      07-6月 -00
# 1         08000598      17-6月 -00
# 2         08000279      10-6月 -00
# 3         08000279      10-6月 -00
# 4         08000279      10-6月 -00
# 5         08000279      10-6月 -00
# 6         08000279      10-6月 -00
# 7         08000279      10-6月 -00
# 8         04012492      25-7月 -00
# 9         06001257      29-6月 -00
# 10        06001257      29-6月 -00
# 11        06001257      29-6月 -00
# 12        06001257      29-6月 -00
# 13        06001257      29-6月 -00
# 14        06001257      29-6月 -00
# 15        06001257      29-6月 -00
# 16        04012492      25-7月 -00
# 17        04004716      25-7月 -00
# 18        07002615      04-6月 -00
# 19        07002615      04-6月 -00
# 20        07002615      04-6月 -00
# 21        04005889      16-6月 -00
# 22        04010327      30-6月 -00
# 23        04010327      30-6月 -00
# 24        04010327      30-6月 -00
# 25        04010327      30-6月 -00
# ...

# %%
DATA_count = PAT_DATA[PAT_DATA['PATIENT_ID'].isin(DF)]

# %%
DATA_count
# Out:
#         PATIENT_ID DIAGNOSIS_DATE
# 0         08000598      07-6月 -00
# 1         08000598      17-6月 -00
# 139       04008472      30-6月 -00
# 140       04008472      30-6月 -00
# 157       06000797      30-4月 -00
# 158       06000797      30-4月 -00
# 159       06000797      30-4月 -00
# 160       06000797      30-4月 -00
# 161       06000797      30-4月 -00
# 162       06000797      30-4月 -00
# 172       04008741      23-5月 -00
# 174       04008741      23-5月 -00
# 175       04008741      23-5月 -00
# 376       09000110      25-5月 -00
# 377       09000110      25-5月 -00
# 378       09000110      25-5月 -00
# 379       09000110      25-5月 -00
# 380       09000110      25-5月 -00
# 452       04008472      22-5月 -00
# 454       04008472      22-5月 -00
# 459       04008472      22-5月 -00
# 602       04005437      12-6月 -00
# 603       04005437      12-6月 -00
# 604       04005437      12-6月 -00
# 692       04005863      19-6月 -00
# 693       04005863      19-6月 -00
# ...

# %%
DATA_count.to_csv("F:/data/output/疾病1日期.tsv")

# %%
# 9.4 表 去重
PAT_SAME = pd.read_csv('F:/data/input/表9_4去重.txt', sep='\t')

# %%
PAT_SAME
# Out:
#        PATIENT_ID  DIAGNOSIS_DATE
# 0         8000598          2000.0
# 1         4008472          2000.0
# 2         6000797          2000.0
# 3         4008741          2000.0
# 4         9000110          2000.0
# 5         4005437          2000.0
# 6         4005863          2000.0
# 7         8000549          2000.0
# 8         4000808          2000.0
# 9         8000656          2000.0
# 10        4001909          2000.0
# 11        8000092          2000.0
# 12        8000152          2000.0
# 13        4010856          2000.0
# 14        8000591          2000.0
# 15        4001204          2000.0
# 16        4005406          2000.0
# 17        4005323          2000.0
# 18        8000463          2000.0
# 19        8000489          2000.0
# 20        8000052          2000.0
# 21        8000019          2000.0
# 22        4131486          2000.0
# 23        4012824          2000.0
# 24        6000572          2000.0
# 25        4064341          2000.0
# ...

# %%
PAT_NO_SAME = PAT_SAME.drop_duplicates(['PATIENT_ID'],'last')
PAT_NO_SAME
# Out:
#        PATIENT_ID  DIAGNOSIS_DATE
# 768       4236424          2008.0
# 790       4236770          2008.0
# 1457      4020394          2005.0
# 1613      4025545          2005.0
# 1646      4231692          2008.0
# 1648      6002001          2008.0
# 1653      8000205          2008.0
# 1679      4386751          2010.0
# 1680      4160318          2010.0
# 1681      4401355          2010.0
# 1686      4372346          2010.0
# 1694      4387150          2010.0
# 1695      4391229          2010.0
# 1701      4381421          2010.0
# 1706      4088485          2010.0
# 1709      4185391          2010.0
# 1714      4362023          2010.0
# 1715      8001727          2010.0
# 1716      8001568          2010.0
# 1727      4147051          2010.0
# 1731      4390956          2010.0
# 1734      4022113          2010.0
# 1735      4067149          2010.0
# 1736      4355640          2010.0
# 1741      4379888          2010.0
# 1745      4381600          2010.0
# ...

# %%
PAT_NO_SAME.to_csv("F:/data/output/去重后的就诊日期表.tsv")

# %%
# 输出频率疾病信息表
DIA_count = DIAGNOSTIC_CATEGORY_1['DIAGNOSIS_CODE'].value_counts()
DIA_count.to_csv("F:/data/output/频率疾病信息表.tsv")

# %%
ILL_ID  = pd.read_csv('F:/data/input/频率疾病信息表.tsv', sep='\t')
DF_1 = ILL_ID['ILL']
DF_1
# Out:
# 0                 E11.901
# 1                 I10  06
# 2                 I10  03
# 3                 I25.101
# 4                 I63.901
# 5                 J98.403
# 6                 Z98.819
# 7                 I10  05
# 8                 Z34.801
# 9                 X59.903
# 10                Z38.001
# 11                D64.902
# 12                S69.903
# 13                414.001
# 14                E11.504
# 15                C34.901
# 16                I69.301
# 17                S68.101
# 18                401.903
# 19                J18.901
# 20                K29.502
# 21                E14.901
# 22                S66.902
# 23                M51.201
# 24                401.907
# 25                W31.904
# 26                Z37.001
# 27                E77.801
# 28                N40  01
# 29                465.901
#                ...
# 10158            E900.101
# 10159             N01.702
# 10160             N01.901
# 10161             S01.103
# ...

# %%
ILL_DUIZHAO  = pd.read_csv('F:/data/input/表4_1疾病信息对应表.tsv', sep='\t')
ILL_DUIZHAO
# Out:
#       DIAGNOSIS_CODE     DIAGNOSIS_NAME  STD_INDICATOR  APPROVED_INDICATOR  \
# 0            H40.207           慢性闭角型青光眼              1                   1
# 1            H40.208           虹膜高褶型青光眼              1                   1
# 2            H40.301             创伤性青光眼              1                   1
# 3            H40.401        青光眼并发虹膜睫状体炎              1                   1
# 4            H40.402          青光眼睫状体炎危象              1                   1
# 5            H40.503           新生血管性青光眼              1                   1
# 6            H40.504             继发性青光眼              1                   1
# 7            H40.505       青光眼并发视网膜静脉阻塞              1                   1
# 8            H40.506           晶体脱位后青光眼              1                   1
# 9            H40.507          晶状体溶解性青光眼              1                   1
# 10           H40.508            无晶体性青光眼              1                   1
# ...

# %%
test1 = ILL_DUIZHAO[ILL_DUIZHAO['DIAGNOSIS_CODE'].isin(DF_1)]
test1.to_csv("F:/data/output/疾病频率中文对照表.tsv")

# %%
ILL_ID_1  = pd.read_csv('F:/data/input/统计前一百.tsv', sep='\t')
DF_2 = ILL_ID_1['ILL']
DF_2
# Out:
# 0     E11.901
# 1     I10  06
# 2     I10  03
# 3     I25.101
# 4     I63.901
# 5     J98.403
# 6     Z98.819
# 7     I10  05
# 8     Z34.801
# 9     X59.903
# 10    Z38.001
# 11    D64.902
# 12    S69.903
# 13    414.001
# 14    E11.504
# 15    C34.901
# 16    I69.301
# 17    S68.101
# 18    401.903
# 19    J18.901
# 20    K29.502
# 21    E14.901
# 22    S66.902
# 23    M51.201
# 24    401.907
# 25    W31.904
# 26    Z37.001
# 27    E77.801
# 28    N40  01
# 29    465.901
#        ...
# 70    K92.204
# 71    401.902
# 72    250.003
# 73    V70.001
# 74    K56.701
# 75    Z98.829
# 76    J44.901
# 77    L40.901
# 78    K31.701
# 79    N18.901
# 80    M47.821
# 81    518.801
# 82    V22.201
# 83    R94.501
# 84    J42  03
# 85    O80.901
# 86    E78.501
# 87    R10.401
# 88    Z93.001
# 89    T14.003
# 90    L89  01
# 91    O42.901
# 92    I11.901
# 93    295.901
# 94    I50.903
# 95    J94.803
# 96    S32.001
# 97    162.901
# 98    J42  02
# 99    959.501
# ...

# %%
test2 = ILL_DUIZHAO[ILL_DUIZHAO['DIAGNOSIS_CODE'].isin(DF_2)]

# %%
test2.to_csv("F:/data/output/前一百疾病频率中文对照表.tsv")

# %%
alist_1 = ['E10.901']
OUT_TangE10 = DIAGNOSTIC_CATEGORY[DIAGNOSTIC_CATEGORY['DIAGNOSIS_CODE'].isin(alist_1)]
OUT_TangE10
OUT_TangE10.to_csv("F:/data/output/糖尿病E10信息.tsv")

# %%
alist_2=['E14.901']
Out_TangE14 = DIAGNOSTIC_CATEGORY[DIAGNOSTIC_CATEGORY['DIAGNOSIS_CODE'].isin(alist_2)]
Out_TangE14
Out_TangE14.to_csv("F:/data/output/糖尿病E14信息.tsv")

# %%
OUT_TangE10
# Out:
#         PATIENT_ID  VISIT_ID DIAGNOSIS_TYPE  DIAGNOSIS_NO DIAGNOSIS_CODE  \
# 254274    04000997         4              2             3        E10.901
# 254277    04000997         4              3             3        E10.901
# 257448    04030316         2              1             1        E10.901
# 259205    07012647         1              1             1        E10.901
# 259206    07012647         1              2             1        E10.901
# 259207    07012647         1              3             1        E10.901
# 260093    04256855         1              2             1        E10.901
# 260096    04256855         1              3             1        E10.901
# 265225    07017898         1              2             2        E10.901
# 266210    07017898         2              2             2        E10.901
# 266213    07017898         2              3             2        E10.901
# 267924    04294358         1              1             1        E10.901
# ...

# %%
#筛选出频率E10.901 疾病的实际患病人数 112人
DF_E10 = OUT_TangE10['PATIENT_ID'].unique()   
#转格式
SS_E10 = Series(DF_E10)
SS_E10
# Out:
# 0      04000997
# 1      04030316
# 2      07012647
# 3      04256855
# 4      07017898
# 5      04294358
# 6      07025700
# 7      04014442
# 8      04205533
# 9      04268437
# 10     04316909
# 11     08001236
# 12     04067899
# 13     04371961
# 14     04368077
# 15     04099960
# 16     04180374
# 17     06001687
# 18     04037492
# 19     04201827
# 20     04277849
# 21     07002616
# 22     04267230
# 23     04042485
# 24     04368430
# 25     04066218
# 26     04102939
# 27     04371391
# 28     04317810
# 29     04009024
#          ...
# 82     04856143
# 83     04224013
# 84     04903734
# 85     07047355
# 86     04899785
# 87     04935061
# 88     04922829
# 89     04942011
# 90     04912332
# 91     07038329
# 92     04938745
# 93     07092845
# 94     04948002
# 95     04949105
# 96     04941873
# 97     04971142
# 98     02000339
# 99     08001553
# 100    04817667
# 101    04927665
# 102    04870561
# 103    04914247
# 104    04930671
# 105    07098527
# ...

# %%
Out_TangE14
# Out:
#         PATIENT_ID  VISIT_ID DIAGNOSIS_TYPE  DIAGNOSIS_NO DIAGNOSIS_CODE  \
# 241083    04415618         2              1             1        E14.901
# 241449    04449557         1              1             1        E14.901
# 241511    04064208        17              2             4        E14.901
# 241517    04064208        17              3             4        E14.901
# 241719    04457799         1              1             1        E14.901
# 241723    04457799         1              A             3        E14.901
# 241896    04106429         8              A             5        E14.901
# 241949    04451323         1              1             1        E14.901
# 242034    04423285         2              2             3        E14.901
# 242036    04423285         2              A             1        E14.901
# 242067    04451713         2              2             4        E14.901
# 242071    04451713         2              A             3        E14.901
# ...

# %%
#筛选出频率E14.901 疾病的实际患病人数 2887人
DF_E14 = Out_TangE14['PATIENT_ID'].unique()   
#转格式
SS_E14 = Series(DF_E14)
SS_E14
# Out:
# 0       04415618
# 1       04449557
# 2       04064208
# 3       04457799
# 4       04106429
# 5       04451323
# 6       04423285
# 7       04451713
# 8       04180061
# 9       04445883
# 10      04332973
# 11      04465841
# 12      04450158
# 13      04454233
# 14      06000110
# 15      04397469
# 16      04112631
# 17      04015466
# 18      04014160
# 19      06003937
# 20      04458566
# 21      08000883
# 22      04038438
# 23      08001119
# 24      04001204
# 25      04077039
# 26      04454566
# 27      06001260
# 28      04068446
# 29      04003714
#           ...
# 2857    04369505
# 2858    04936996
# 2859    04002587
# 2860    04951182
# 2861    04987697
# 2862    04958800
# 2863    04983628
# 2864    04632742
# 2865    04058474
# 2866    04984654
# 2867    90203673
# 2868    04985572
# 2869    04403466
# 2870    04986802
# 2871    04929228
# 2872    02001634
# 2873    04945023
# 2874    04035899
# 2875    04957606
# 2876    04956729
# 2877    04995790
# ...

# %%
DF_E14
# Out:
# array(['04415618', '04449557', '04064208', ..., 4394714, 4549879, 4547713],
#       dtype=object)

# %%
DF_E10
# Out:
# array(['04000997', '04030316', '07012647', '04256855', '07017898',
#        '04294358', '07025700', '04014442', '04205533', '04268437',
#        '04316909', '08001236', '04067899', '04371961', '04368077',
#        '04099960', '04180374', '06001687', '04037492', '04201827',
#        '04277849', '07002616', '04267230', '04042485', '04368430',
#        '04066218', '04102939', '04371391', '04317810', '04009024',
#        '04323013', '04311124', '04120085', '04286424', '07017279',
#        '07031267', '04433905', '04410854', '04427293', '04242798',
#        '07045729', '04552855', '04287440', '04682304', '04650740',
#        '04622330', '04597097', '04577885', '04015320', '04635458',
#        '04473988', '07050312', '04781837', '04735082', '04924510',
#        '06001828', '04570541', '04296502', '04674497', '04092112',
#        '04831791', '07056312', '04871776', '07085842', '04156075',
#        '04548773', '04820464', '04765011', '04762919', '04113063',
# ...

# %%
# 9.1 表 病人主索引  PAT_MASTER_INDEX 预处理后
PAT_MASTER_INDEX = pd.read_csv('F:/data/input/病人主索引_预.tsv', sep='\t')

# %%
# 输出9.1表中患有E10.901 疾病的人的信息（病人ID、性别、年龄）
output_E10_901 = PAT_MASTER_INDEX[PAT_MASTER_INDEX['PATIENT_ID'].isin(DF_E10)]

#输出疾病E10.901信息
output_E10_901.to_csv("F:/data/output/疾病E10_901信息_病人性别年龄.tsv")

# %%
# 输出9.1表中患有E14.901 疾病的人的信息（病人ID、性别、年龄）
output_E14_901 = PAT_MASTER_INDEX[PAT_MASTER_INDEX['PATIENT_ID'].isin(DF_E14)]
#输出疾病E14.901信息
output_E14_901.to_csv("F:/data/output/疾病E14_901信息_病人性别年龄.tsv")

# %%
# 9.4 表 诊断记录  预处理后
PAT_DATA = pd.read_csv('F:/data/input/就诊日期.tsv', sep='\t')

# %%
PAT_DATA
# Out:
#         PATIENT_ID DIAGNOSIS_DATE
# 0         08000598      07-6月 -00
# 1         08000598      17-6月 -00
# 2         08000279      10-6月 -00
# 3         08000279      10-6月 -00
# 4         08000279      10-6月 -00
# 5         08000279      10-6月 -00
# 6         08000279      10-6月 -00
# 7         08000279      10-6月 -00
# 8         04012492      25-7月 -00
# 9         06001257      29-6月 -00
# 10        06001257      29-6月 -00
# 11        06001257      29-6月 -00
# 12        06001257      29-6月 -00
# 13        06001257      29-6月 -00
# 14        06001257      29-6月 -00
# 15        06001257      29-6月 -00
# 16        04012492      25-7月 -00
# 17        04004716      25-7月 -00
# 18        07002615      04-6月 -00
# 19        07002615      04-6月 -00
# 20        07002615      04-6月 -00
# 21        04005889      16-6月 -00
# 22        04010327      30-6月 -00
# 23        04010327      30-6月 -00
# 24        04010327      30-6月 -00
# 25        04010327      30-6月 -00
# ...

# %%
# 含重复信息的就诊E10信息
DATA_count_E10 = PAT_DATA[PAT_DATA['PATIENT_ID'].isin(DF_E10)]
DATA_count_E10
# Out:
#         PATIENT_ID DIAGNOSIS_DATE
# 4625      04000997      09-5月 -00
# 4626      04000997      09-5月 -00
# 4631      04000997      09-5月 -00
# 5875      04067899      27-1月 -00
# 5876      04067899      27-1月 -00
# 5877      04067899      27-1月 -00
# 5878      04067899      27-1月 -00
# 5879      04067899      27-1月 -00
# 8585      04015320      30-10月-00
# 8586      04015320      30-10月-00
# 8587      04015320      30-10月-00
# 12924     04067899      07-6月 -00
# 12925     04067899      07-6月 -00
# 12926     04067899      07-6月 -00
# 12927     04067899      07-6月 -00
# 12928     04067899      07-6月 -00
# 12929     04067899      07-6月 -00
# 12930     04067899      07-6月 -00
# 12931     04067899      09-9月 -00
# 16723     04067899      22-9月 -00
# 16724     04067899      22-9月 -00
# 16725     04067899      22-9月 -00
# 16726     04067899      22-9月 -00
# 16727     04067899      22-9月 -00
# 16728     04067899      22-9月 -00
# 16729     04067899      22-9月 -00
# ...

# %%
# E10 就诊日期信息
PAT_NO_SAME_E10 = DATA_count_E10.drop_duplicates(['PATIENT_ID'],'last')
PAT_NO_SAME_E10
PAT_NO_SAME_E10.to_csv("F:/data/output/疾病E10_901信息_病人就诊日期.tsv")

# %%
DATA_count_E14 = PAT_DATA[PAT_DATA['PATIENT_ID'].isin(DF_E14)]
DATA_count_E14
# Out:
#         PATIENT_ID DIAGNOSIS_DATE
# 0         08000598      07-6月 -00
# 1         08000598      17-6月 -00
# 139       04008472      30-6月 -00
# 140       04008472      30-6月 -00
# 157       06000797      30-4月 -00
# 158       06000797      30-4月 -00
# 159       06000797      30-4月 -00
# 160       06000797      30-4月 -00
# 161       06000797      30-4月 -00
# 162       06000797      30-4月 -00
# 172       04008741      23-5月 -00
# 174       04008741      23-5月 -00
# 175       04008741      23-5月 -00
# 376       09000110      25-5月 -00
# 377       09000110      25-5月 -00
# 378       09000110      25-5月 -00
# 379       09000110      25-5月 -00
# 380       09000110      25-5月 -00
# 452       04008472      22-5月 -00
# 454       04008472      22-5月 -00
# 459       04008472      22-5月 -00
# 602       04005437      12-6月 -00
# 603       04005437      12-6月 -00
# 604       04005437      12-6月 -00
# 692       04005863      19-6月 -00
# 693       04005863      19-6月 -00
# ...

# %%
# E14 就诊日期信息
PAT_NO_SAME_E14 = DATA_count_E14.drop_duplicates(['PATIENT_ID'],'last')
PAT_NO_SAME_E14
# Out:
#         PATIENT_ID DIAGNOSIS_DATE
# 288028    04395914      05-11月-10
# 288332    04372346      12-9月 -10
# 290005    04020394      30-9月 -10
# 290393    04247492      14-10月-10
# 291469    04383215      14-9月 -10
# 291490    04024336      27-8月 -10
# 291672    04389456      07-10月-10
# 292712    04393691      22-10月-10
# 293464    04388590      05-10月-10
# 293990    04169768      11-10月-10
# 294138    04394557      30-10月-10
# 296673    04270949      16-12月-08
# 297012    04271578      16-3月 -09
# 297547    04276861      04-3月 -09
# 297838    04142075      17-11月-08
# 298513    04275601      11-2月 -09
# 298890    04000217      09-12月-08
# 299775    08000012      13-11月-08
# 301694    04264653      03-11月-08
# 301733    04163182      03-11月-08
# 301904    04272214      28-12月-08
# 305657    04315649      30-8月 -09
# 306135    04286602      18-5月 -09
# 307856    04315889      29-8月 -09
# 308154    04086672      25-6月 -09
# 308621    04271316      30-12月-08
# ...

# %%
PAT_NO_SAME_E14.to_csv("F:/data/output/疾病E14_901信息_病人就诊日期.tsv")

# %%
ID_Judge_Same = pd.read_csv('F:/data/input/ID重复判断.tsv', sep='\t')
ID_Judge_Same
# Out:
#        PATIENT_ID
# 0         4971445
# 1         4972977
# 2         4921331
# 3         4120085
# 4         4368077
# 5         4368077
# 6         4427293
# 7         4427293
# 8         4674497
# 9         4935061
# 10        4972976
# 11        4981557
# 12        4998184
# 13        7081584
# 14        7092845
# 15        7094987
# 16        4345572
# 17        4532956
# 18        4573187
# 19        4668451
# 20        4794857
# 21        7025700
# 22        4345572
# 23        4403985
# 24        4794857
# 25        4479428
# 26        4371391
# 27        7056312
# 28        4479428
# 29        4674066
# ...           ...
# 12081     4989676
# 12082     6000110
# 12083     6000656
# 12084    90151944
# 12085     4105692
# 12086     4983661
# 12087     6000110
# 12088     6000656
# 12089     4099327
# 12090     4993430
# 12091      941327
# 12092     4492605
# 12093     2000253
# 12094     4225724
# 12095     4883229
# 12096     4896745
# 12097     4906604
# 12098     4265000
# ...

# %%
DF_ID_Judge_Same = ID_Judge_Same['PATIENT_ID'].unique()   
#转格式
SS_ID_Judge_Same = Series(DF_ID_Judge_Same)
SS_ID_Judge_Same
# Out:
# 0         4971445
# 1         4972977
# 2         4921331
# 3         4120085
# 4         4368077
# 5         4427293
# 6         4674497
# 7         4935061
# 8         4972976
# 9         4981557
# 10        4998184
# 11        7081584
# 12        7092845
# 13        7094987
# 14        4345572
# 15        4532956
# 16        4573187
# 17        4668451
# 18        4794857
# 19        7025700
# 20        4403985
# 21        4479428
# 22        4371391
# 23        7056312
# 24        4674066
# 25        4940588
# 26        4005008
# 27        4488405
# 28        4608567
# 29        4831791
#            ...
# 10397     4095751
# 10398     4105692
# 10399     4168626
# 10400     4216172
# 10401     4581265
# 10402     4597728
# 10403     4600302
# 10404     4983661
# 10405     4989676
# 10406     6000110
# 10407     6000656
# 10408    90151944
# 10409     4099327
# 10410     4993430
# 10411      941327
# 10412     4492605
# 10413     2000253
# 10414     4225724
# 10415     4883229
# ...

# %%
ID_Judge_Same = pd.read_csv('F:/data/input/ID重复判断.tsv', sep='\t')
ID_Judge_Same['PATIENT_ID'].value_counts()
# Out:
# 4067899    3
# 8001236    3
# 7047355    3
# 4268437    3
# 4000997    3
# 4903734    3
# 4099960    3
# 4287440    3
# 4570541    3
# 4030316    3
# 4256855    3
# 7045729    3
# 7038329    3
# 4685775    3
# 4927435    2
# 4153253    2
# 4067279    2
# 4086684    2
# 4294073    2
# 4072214    2
# 4699852    2
# 4224447    2
# 4477065    2
# 6002115    2
# 4568480    2
# 4145349    2
# 4185891    2
# 4616387    2
# 4178675    2
# 4974561    2
#           ..
# 4532384    1
# 4567511    1
# 4704476    1
# 4284633    1
# 4952279    1
# 4741334    1
# 4638932    1
# 4041390    1
# 4434128    1
# 4589209    1
# 4446463    1
# 4634858    1
# 4780286    1
# 4346095    1
# 4501763    1
# 4768013    1
# 4568393    1
# 4956425    1
# 4788487    1
# 4178181    1
# 4999428    1
# 4487426    1
# 4958448    1
# 4575487    1
# 4741374    1
# 4391165    1
# 4535229    1
# 4806902    1
# 4950260    1
# 4920236    1
# Name: PATIENT_ID, Length: 10427, dtype: int64

# %%
output_judge = ID_Judge_Same['PATIENT_ID'].value_counts()
output_judge.to_csv('F:/data/output/糖尿病去重ID频率统计.tsv')

# %%
#################高血压#######################

# %%
# 表4.1 疾病字典 DIAGNOSIS_DICT  获得疾病代码
DIAGNOSIS_DICT = pd.read_csv('F:/data/input/诊断代码.tsv', sep='\t')

# %%
print(DIAGNOSIS_DICT)
# Out:
#          DIAGNOSIS_CODE DIAGNOSIS_NAME  STD_INDICATOR  APPROVED_INDICATOR  \
# 0               Z99.201   肾脏透析(CAPD)状态              1                   1
# 1               Z99.101        依赖于呼吸器者              1                   1
# 2               Z98.881       皮肤恶性肿瘤术后              1                   1
# 3               Z98.880         心肺复苏术后              1                   1
# 4               Z98.879          鼻整形术后              1                   1
# 5               Z98.878        头面部肿瘤术后              1                   1
# 6               Z98.877           吸脂术后              1                   1
# 7               Z98.875        肾结石碎石术后              1                   1
# 8               Z98.874        脊柱内固定术后              1                   1
# 9               Z98.873    支气管动脉栓塞治疗术后              1                   1
# 10              Z98.872         阑尾切除术后              1                   1
# 11              Z98.871       胸腔肿瘤切除术后              1                   1
# ...

# %%
# 经检验 需要全部字段 此处重做 表9.7 诊断分类记录 DIAGNOSTIC_CATEGORY 预处理 得到病人ID和疾病ID
DIAGNOSTIC_CATEGORY = pd.read_csv('F:/data/input/诊断分类记录_全.tsv', sep='\t')
# Out:
# d:\programdata\anaconda3\envs\tensorflow\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (0,2) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
print(DIAGNOSTIC_CATEGORY)
# Out:
#         PATIENT_ID  VISIT_ID DIAGNOSIS_TYPE  DIAGNOSIS_NO    DIAGNOSIS_CODE  \
# 0         04003500         2              2             1           261  01
# 1         04003500         2              3             1           307.101
# 2         04003500         2              3             2           273.801
# 3         04003500         2              3             3           280  01
# 4         04010720         1              5             1           799.402
# 5         04010720         1              6             1           567.905
# 6         04007153         1              1             1  070.901+573.106*
# 7         04007153         1              2             1  070.901+573.106*
# 8         04007153         1              3             1           155.201
# 9         04017543         1              1             1           162.901
# 10        04017543         1              2             1           793.101
# ...

# %%
#高血压三级
alist=['I10  06']
DIAGNOSTIC_CATEGORY[DIAGNOSTIC_CATEGORY['DIAGNOSIS_CODE'].isin(alist)]
# Out:
#         PATIENT_ID  VISIT_ID DIAGNOSIS_TYPE  DIAGNOSIS_NO DIAGNOSIS_CODE  \
# 240979    04051346         7              2             1        I10  06
# 240980    04051346         7              3             1        I10  06
# 241016    07056873         1              2             2        I10  06
# 241022    07056873         1              A             1        I10  06
# 241095    04282667         1              1             1        I10  06
# 241102    04451590         1              1             1        I10  06
# 241219    06003511        11              A             1        I10  06
# 241323    04069705        26              A             2        I10  06
# 241369    04323020         7              2             5        I10  06
# 241388    04323020         7              3             5        I10  06
# 241544    04457841         1              3             2        I10  06
# 241549    04457844         1              2             1        I10  06
# ...

# %%
#重定义
test = DIAGNOSTIC_CATEGORY[DIAGNOSTIC_CATEGORY['DIAGNOSIS_CODE'].isin(alist)]
print(test)
# Out:
#         PATIENT_ID  VISIT_ID DIAGNOSIS_TYPE  DIAGNOSIS_NO DIAGNOSIS_CODE  \
# 240979    04051346         7              2             1        I10  06
# 240980    04051346         7              3             1        I10  06
# 241016    07056873         1              2             2        I10  06
# 241022    07056873         1              A             1        I10  06
# 241095    04282667         1              1             1        I10  06
# 241102    04451590         1              1             1        I10  06
# 241219    06003511        11              A             1        I10  06
# 241323    04069705        26              A             2        I10  06
# 241369    04323020         7              2             5        I10  06
# 241388    04323020         7              3             5        I10  06
# 241544    04457841         1              3             2        I10  06
# 241549    04457844         1              2             1        I10  06
# ...

# %%
#筛选出频率高血压三级的实际患病人数 6049人
DF = test['PATIENT_ID'].unique()   
#转格式
SS = Series(DF)
SS
# Out:
# 0       04051346
# 1       07056873
# 2       04282667
# 3       04451590
# 4       06003511
# 5       04069705
# 6       04323020
# 7       04457841
# 8       04457844
# 9       04454174
# 10      04411099
# 11      04131836
# 12      04161415
# 13      04230295
# 14      04326035
# 15      04068254
# 16      04460009
# 17      04106429
# 18      04261192
# 19      04466586
# 20      04077673
# 21      04101020
# 22      04327447
# 23      04462284
# 24      04465841
# 25      04465957
# 26      04442951
# 27      04432732
# 28      04178011
# 29      08000490
#           ...
# 6019    04959616
# 6020    04960604
# 6021    04950308
# 6022    04706290
# 6023    04993834
# 6024    04350367
# 6025    04478581
# 6026    04998178
# 6027    04770494
# 6028    04983768
# 6029    04989682
# 6030    04009549
# 6031    04986336
# 6032    04998435
# 6033    04963808
# 6034    90220533
# 6035    02000674
# 6036    04883819
# 6037    04251964
# 6038     4030598
# 6039     4944210
# ...

# %%
#病人ID
DF
# Out:
# array(['04051346', '07056873', '04282667', ..., 4394714, 4946613, 4802412],
#       dtype=object)

# %%
# 9.1 表 病人主索引  PAT_MASTER_INDEX 预处理后
PAT_MASTER_INDEX = pd.read_csv('F:/data/input/病人主索引_预.tsv', sep='\t')

# %%
# 输出9.1表中患有高血压 疾病的人的信息（病人ID、性别、年龄）
PAT_MASTER_INDEX[PAT_MASTER_INDEX['PATIENT_ID'].isin(DF)]
# Out:
#         PATIENT_ID SEX DATE_OF_BIRTH
# 19        08000278   男     01-4月 -26
# 148       09000865   男     01-11月-39
# 273       08000570   男     02-11月-25
# 400       07001157   男     29-7月 -60
# 413       08000596   男     01-10月-29
# 415       08000597   男     01-9月 -28
# 491       08000300   男     01-11月-29
# 546       04000217   男     01-1月 -22
# 549       04002205   女     06-7月 -30
# 555       04002944   男     25-11月-39
# 587       04002544   男     16-12月-30
# 688       08000299   男     01-1月 -26
# 708       08000118   男     08-12月-22
# 838       04005039   女     01-1月 -31
# 882       09000831   男     01-2月 -48
# 916       08000129   男     01-10月-14
# 1009      08000212   女     01-10月-23
# 1099      07027413   女     01-9月 -63
# 1206      06001077   男     17-7月 -53
# 1246      09000327   男     01-8月 -63
# 1276      08000304   男     01-7月 -28
# 1297      08000310   男     01-1月 -33
# 1485      04008700   女     08-3月 -33
# 1499      09000470   女     01-11月-39
# ...

# %%
output_sex = PAT_MASTER_INDEX[PAT_MASTER_INDEX['PATIENT_ID'].isin(DF)]

# %%
#输出疾病1信息
output_sex.to_csv("F:/data/output/高血压三级_年龄_性别_信息.tsv")

# %%
# 9.4 表 诊断记录  预处理后
PAT_DATA = pd.read_csv('F:/data/input/就诊日期.tsv', sep='\t')

# %%
PAT_DATA
# Out:
#         PATIENT_ID DIAGNOSIS_DATE
# 0         08000598      07-6月 -00
# 1         08000598      17-6月 -00
# 2         08000279      10-6月 -00
# 3         08000279      10-6月 -00
# 4         08000279      10-6月 -00
# 5         08000279      10-6月 -00
# 6         08000279      10-6月 -00
# 7         08000279      10-6月 -00
# 8         04012492      25-7月 -00
# 9         06001257      29-6月 -00
# 10        06001257      29-6月 -00
# 11        06001257      29-6月 -00
# 12        06001257      29-6月 -00
# 13        06001257      29-6月 -00
# 14        06001257      29-6月 -00
# 15        06001257      29-6月 -00
# 16        04012492      25-7月 -00
# 17        04004716      25-7月 -00
# 18        07002615      04-6月 -00
# 19        07002615      04-6月 -00
# 20        07002615      04-6月 -00
# 21        04005889      16-6月 -00
# 22        04010327      30-6月 -00
# 23        04010327      30-6月 -00
# 24        04010327      30-6月 -00
# 25        04010327      30-6月 -00
# ...

# %%
DATA_count = PAT_DATA[PAT_DATA['PATIENT_ID'].isin(DF)]

# %%
DATA_count
# Out:
#         PATIENT_ID DIAGNOSIS_DATE
# 0         08000598      07-6月 -00
# 1         08000598      17-6月 -00
# 139       04008472      30-6月 -00
# 140       04008472      30-6月 -00
# 157       06000797      30-4月 -00
# 158       06000797      30-4月 -00
# 159       06000797      30-4月 -00
# 160       06000797      30-4月 -00
# 161       06000797      30-4月 -00
# 162       06000797      30-4月 -00
# 388       04032188      24-5月 -00
# 389       04032188      24-5月 -00
# 390       04032188      24-5月 -00
# 391       04032188      24-5月 -00
# 392       04032188      24-5月 -00
# 452       04008472      22-5月 -00
# 454       04008472      22-5月 -00
# 459       04008472      22-5月 -00
# 540       04032188      09-6月 -00
# 544       04032188      09-6月 -00
# 552       04032188      09-6月 -00
# 555       04032188      09-6月 -00
# 562       04032188      09-6月 -00
# 710       08000549      15-6月 -00
# 711       08000549      15-6月 -00
# 712       08000549      15-6月 -00
# ...

# %%
PAT_NO_SAME_1 = DATA_count.drop_duplicates(['PATIENT_ID'],'last')
PAT_NO_SAME_1
# Out:
#         PATIENT_ID DIAGNOSIS_DATE
# 288359    04393224      18-10月-10
# 289280    04083884      02-10月-10
# 289689    04258416      25-5月 -10
# 289908    04384270      16-9月 -10
# 290005    04020394      30-9月 -10
# 290393    04247492      14-10月-10
# 291279    04164974      30-8月 -10
# 291469    04383215      14-9月 -10
# 291490    04024336      27-8月 -10
# 292848    04017234      18-9月 -10
# 293332    04335338      09-9月 -10
# 293731    04353751      09-10月-10
# 293990    04169768      11-10月-10
# 293994    04370273      25-10月-10
# 294107    04253637      11-11月-10
# 294194    04091511      25-8月 -10
# 294230    04206732      21-9月 -10
# 294423    04381977      06-9月 -10
# 294840    04278200      09-3月 -09
# 295758    04275193      07-2月 -09
# 296057    04050882      26-11月-08
# 296214    06000055      24-11月-08
# 297070    04232086      09-3月 -09
# 297295    04251321      21-10月-08
# 297813    04190920      07-11月-08
# 298550    04274722      14-2月 -09
# ...

# %%
PAT_NO_SAME_1.to_csv("F:/data/output/高血压三级_就诊日期_信息.tsv")

# %%
#####统计高血压二级信息##########

# %%
# 表4.1 疾病字典 DIAGNOSIS_DICT 
DIAGNOSIS_DICT = pd.read_csv('F:/data/input/诊断代码.tsv', sep='\t')

# %%
# 经检验 需要全部字段 此处重做 表9.7 诊断分类记录 DIAGNOSTIC_CATEGORY 预处理 得到病人ID和疾病ID
DIAGNOSTIC_CATEGORY = pd.read_csv('F:/data/input/诊断分类记录_全.tsv', sep='\t')
# Out:
# d:\programdata\anaconda3\envs\tensorflow\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (0,2) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
print(DIAGNOSTIC_CATEGORY)
# Out:
#         PATIENT_ID  VISIT_ID DIAGNOSIS_TYPE  DIAGNOSIS_NO    DIAGNOSIS_CODE  \
# 0         04003500         2              2             1           261  01
# 1         04003500         2              3             1           307.101
# 2         04003500         2              3             2           273.801
# 3         04003500         2              3             3           280  01
# 4         04010720         1              5             1           799.402
# 5         04010720         1              6             1           567.905
# 6         04007153         1              1             1  070.901+573.106*
# 7         04007153         1              2             1  070.901+573.106*
# 8         04007153         1              3             1           155.201
# 9         04017543         1              1             1           162.901
# 10        04017543         1              2             1           793.101
# ...

# %%
alist=['I10  05']
DIAGNOSTIC_CATEGORY[DIAGNOSTIC_CATEGORY['DIAGNOSIS_CODE'].isin(alist)]
# Out:
#         PATIENT_ID  VISIT_ID DIAGNOSIS_TYPE  DIAGNOSIS_NO DIAGNOSIS_CODE  \
# 240974    04230280        20              A             1        I10  05
# 241091    04031528        19              2             1        I10  05
# 241092    04031528        19              3             1        I10  05
# 241096    04282667         1              2             1        I10  05
# 241099    04282667         1              3             1        I10  05
# 241105    04451590         1              3             2        I10  05
# 241169    04272961         2              A             5        I10  05
# 241354    08000087        30              3             2        I10  05
# 241491    04450203         1              2             3        I10  05
# 241496    04450203         1              3             3        I10  05
# 241689    04457799         1              2             1        I10  05
# 241690    04457799         1              3             1        I10  05
# ...

# %%
#重定义
test = DIAGNOSTIC_CATEGORY[DIAGNOSTIC_CATEGORY['DIAGNOSIS_CODE'].isin(alist)]
print(test)
# Out:
#         PATIENT_ID  VISIT_ID DIAGNOSIS_TYPE  DIAGNOSIS_NO DIAGNOSIS_CODE  \
# 240974    04230280        20              A             1        I10  05
# 241091    04031528        19              2             1        I10  05
# 241092    04031528        19              3             1        I10  05
# 241096    04282667         1              2             1        I10  05
# 241099    04282667         1              3             1        I10  05
# 241105    04451590         1              3             2        I10  05
# 241169    04272961         2              A             5        I10  05
# 241354    08000087        30              3             2        I10  05
# 241491    04450203         1              2             3        I10  05
# 241496    04450203         1              3             3        I10  05
# 241689    04457799         1              2             1        I10  05
# 241690    04457799         1              3             1        I10  05
# ...

# %%
#筛选出频率第一疾病的实际患病人数 2889人
DF = test['PATIENT_ID'].unique()   
#转格式
SS = Series(DF)
SS
# Out:
# 0       04230280
# 1       04031528
# 2       04282667
# 3       04451590
# 4       04272961
# 5       08000087
# 6       04450203
# 7       04457799
# 8       04418905
# 9       04123900
# 10      04115848
# 11      08000304
# 12      04180061
# 13      04403145
# 14      04297177
# 15      04085091
# 16      04095165
# 17      04454247
# 18      04320683
# 19      04460723
# 20      08001350
# 21      04446959
# 22      08000673
# 23      04101199
# 24      04047756
# 25      08001649
# 26      07057456
# 27      04459608
# 28      04319262
# 29      04105953
#           ...
# 2859    04985346
# 2860    04042041
# 2861    04562405
# 2862    04998399
# 2863    04967079
# 2864    04981091
# 2865    04998250
# 2866    04328825
# 2867    04998721
# 2868    04714651
# 2869    04703346
# 2870    04801179
# 2871    04941588
# 2872    04652917
# 2873    04966364
# 2874    04537352
# 2875    04955220
# 2876    04912024
# 2877    04872064
# 2878    04098685
# 2879    04978492
# ...

# %%
#病人ID
DF
# Out:
# array(['04230280', '04031528', '04282667', ..., 4931356, 4961930, 4469763],
#       dtype=object)

# %%
# 9.1 表 病人主索引  PAT_MASTER_INDEX 预处理后
PAT_MASTER_INDEX = pd.read_csv('F:/data/input/病人主索引_预.tsv', sep='\t')

# %%
# 输出9.1表中患有高血压 疾病的人的信息（病人ID、性别、年龄）
PAT_MASTER_INDEX[PAT_MASTER_INDEX['PATIENT_ID'].isin(DF)]
# Out:
#         PATIENT_ID SEX DATE_OF_BIRTH
# 77        08000195   男     01-3月 -29
# 151       04001818   男     01-1月 -40
# 273       08000570   男     02-11月-25
# 400       07001157   男     29-7月 -60
# 413       08000596   男     01-10月-29
# 541       09000871   女     01-8月 -53
# 544       08000332   男     07-11月-19
# 616       04002844   男     18-12月-23
# 648       08000041   男     01-9月 -24
# 670       09031128   女     01-5月 -56
# 690       04007573   男     01-1月 -68
# 836       08000471   男     01-3月 -26
# 847       04005034   男     15-8月 -54
# 1144      04001204   男     01-1月 -46
# 1276      08000304   男     01-7月 -28
# 1312      08000362   男     01-5月 -28
# 1327      06000689   男     17-12月-65
# 1329      08000334   男     01-1月 -32
# 1499      09000470   女     01-11月-39
# 1534      08000130   男     01-4月 -20
# 1660      08000167   男     01-5月 -26
# 1671      04001028   女     01-1月 -31
# 1889      08000486   男     01-6月 -26
# 1949      04005028   男     05-4月 -27
# ...

# %%
output_sex = PAT_MASTER_INDEX[PAT_MASTER_INDEX['PATIENT_ID'].isin(DF)]

# %%
#输出疾病1信息
output_sex.to_csv("F:/data/output/高血压二级_年龄_性别_信息.tsv")

# %%
# 9.4 表 诊断记录  预处理后
PAT_DATA = pd.read_csv('F:/data/input/就诊日期.tsv', sep='\t')

# %%
PAT_DATA
# Out:
#         PATIENT_ID DIAGNOSIS_DATE
# 0         08000598      07-6月 -00
# 1         08000598      17-6月 -00
# 2         08000279      10-6月 -00
# 3         08000279      10-6月 -00
# 4         08000279      10-6月 -00
# 5         08000279      10-6月 -00
# 6         08000279      10-6月 -00
# 7         08000279      10-6月 -00
# 8         04012492      25-7月 -00
# 9         06001257      29-6月 -00
# 10        06001257      29-6月 -00
# 11        06001257      29-6月 -00
# 12        06001257      29-6月 -00
# 13        06001257      29-6月 -00
# 14        06001257      29-6月 -00
# 15        06001257      29-6月 -00
# 16        04012492      25-7月 -00
# 17        04004716      25-7月 -00
# 18        07002615      04-6月 -00
# 19        07002615      04-6月 -00
# 20        07002615      04-6月 -00
# 21        04005889      16-6月 -00
# 22        04010327      30-6月 -00
# 23        04010327      30-6月 -00
# 24        04010327      30-6月 -00
# 25        04010327      30-6月 -00
# ...

# %%
DATA_count = PAT_DATA[PAT_DATA['PATIENT_ID'].isin(DF)]

# %%
DATA_count
# Out:
#         PATIENT_ID DIAGNOSIS_DATE
# 172       04008741      23-5月 -00
# 174       04008741      23-5月 -00
# 175       04008741      23-5月 -00
# 376       09000110      25-5月 -00
# 377       09000110      25-5月 -00
# 378       09000110      25-5月 -00
# 379       09000110      25-5月 -00
# 380       09000110      25-5月 -00
# 710       08000549      15-6月 -00
# 711       08000549      15-6月 -00
# 712       08000549      15-6月 -00
# 713       08000549      15-6月 -00
# 714       08000549      15-6月 -00
# 715       08000549      15-6月 -00
# 716       08000549      15-6月 -00
# 717       08000549      15-6月 -00
# 745       04000363      10-4月 -00
# 852       08000656      24-7月 -00
# 1318      08000467      15-5月 -00
# 1319      08000467      15-5月 -00
# 1328      08000379      22-2月 -00
# 1329      08000379      22-2月 -00
# 1330      08000379      22-2月 -00
# 1331      08000379      22-2月 -00
# 1554      09000876      24-3月 -00
# 1555      09000876      24-3月 -00
# ...

# %%
#2886人
PAT_NO_SAME_1 = DATA_count.drop_duplicates(['PATIENT_ID'],'last')
PAT_NO_SAME_1
# Out:
#         PATIENT_ID DIAGNOSIS_DATE
# 288239    04010670      06-9月 -10
# 289268    04388436      30-9月 -10
# 289741    08001727      21-10月-10
# 292340    08001353      26-9月 -10
# 292784    04394810      31-10月-10
# 292806    04384391      29-10月-10
# 294315    04396980      09-11月-10
# 295969    04233003      14-2月 -09
# 298873    04073331      09-1月 -09
# 298965    04270344      13-12月-08
# 301590    04170575      30-12月-08
# 301702    07039506      03-11月-08
# 302339    04012544      31-1月 -09
# 304829    04291969      08-6月 -09
# 306268    04137246      26-7月 -09
# 306378    04045009      18-8月 -09
# 308023    04284689      05-9月 -09
# 308475    04296725      06-8月 -09
# 311303    04166922      29-7月 -09
# 311337    04314000      31-7月 -09
# 311772    04200686      03-7月 -09
# 314791    04341739      27-2月 -10
# 314911    04211684      11-12月-09
# 315005    04204453      24-12月-09
# 315239    04223144      02-2月 -10
# 316121    04334291      06-12月-09
# ...

# %%
PAT_NO_SAME_1.to_csv("F:/data/output/高血压二级_就诊日期_信息.tsv")

# %%
#########高血压一级 I10  04##################

# %%
# 表4.1 疾病字典 DIAGNOSIS_DICT 
DIAGNOSIS_DICT = pd.read_csv('F:/data/input/诊断代码.tsv', sep='\t')

# %%
# 经检验 需要全部字段 此处重做 表9.7 诊断分类记录 DIAGNOSTIC_CATEGORY 预处理 得到病人ID和疾病ID
DIAGNOSTIC_CATEGORY = pd.read_csv('F:/data/input/诊断分类记录_全.tsv', sep='\t')
# Out:
# d:\programdata\anaconda3\envs\tensorflow\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (0,2) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
print(DIAGNOSTIC_CATEGORY)
# Out:
#         PATIENT_ID  VISIT_ID DIAGNOSIS_TYPE  DIAGNOSIS_NO    DIAGNOSIS_CODE  \
# 0         04003500         2              2             1           261  01
# 1         04003500         2              3             1           307.101
# 2         04003500         2              3             2           273.801
# 3         04003500         2              3             3           280  01
# 4         04010720         1              5             1           799.402
# 5         04010720         1              6             1           567.905
# 6         04007153         1              1             1  070.901+573.106*
# 7         04007153         1              2             1  070.901+573.106*
# 8         04007153         1              3             1           155.201
# 9         04017543         1              1             1           162.901
# 10        04017543         1              2             1           793.101
# ...

# %%
alist=['I10  04']
DIAGNOSTIC_CATEGORY[DIAGNOSTIC_CATEGORY['DIAGNOSIS_CODE'].isin(alist)]
# Out:
#         PATIENT_ID  VISIT_ID DIAGNOSIS_TYPE  DIAGNOSIS_NO DIAGNOSIS_CODE  \
# 242277    04234988         2              A             2        I10  04
# 245789    04452761         1              3             3        I10  04
# 245861    09000237        16              A             5        I10  04
# 249282    04456923         1              A             3        I10  04
# 250887   044436054         1              2             1        I10  04
# 250888   044436054         1              3             1        I10  04
# 251994    08000113        12              2             2        I10  04
# 251997    08000113        12              3             2        I10  04
# 252292    07038328         1              3             2        I10  04
# 252735    04271054         1              2             3        I10  04
# 252738    04271054         1              3             3        I10  04
# 256144    07037321         2              2             2        I10  04
# ...

# %%
#重定义
test = DIAGNOSTIC_CATEGORY[DIAGNOSTIC_CATEGORY['DIAGNOSIS_CODE'].isin(alist)]
print(test)
# Out:
#         PATIENT_ID  VISIT_ID DIAGNOSIS_TYPE  DIAGNOSIS_NO DIAGNOSIS_CODE  \
# 242277    04234988         2              A             2        I10  04
# 245789    04452761         1              3             3        I10  04
# 245861    09000237        16              A             5        I10  04
# 249282    04456923         1              A             3        I10  04
# 250887   044436054         1              2             1        I10  04
# 250888   044436054         1              3             1        I10  04
# 251994    08000113        12              2             2        I10  04
# 251997    08000113        12              3             2        I10  04
# 252292    07038328         1              3             2        I10  04
# 252735    04271054         1              2             3        I10  04
# 252738    04271054         1              3             3        I10  04
# 256144    07037321         2              2             2        I10  04
# ...

# %%
#筛选出频率第一疾病的实际患病人数 600人
DF = test['PATIENT_ID'].unique()   
#转格式
SS = Series(DF)
SS
# Out:
# 0       04234988
# 1       04452761
# 2       09000237
# 3       04456923
# 4      044436054
# 5       08000113
# 6       07038328
# 7       04271054
# 8       07037321
# 9       08000377
# 10      07040063
# 11      04000079
# 12      08001377
# 13      08000221
# 14      07033659
# 15      09000528
# 16      08000597
# 17      08000164
# 18      09001193
# 19      07044661
# 20      04367542
# 21      08000282
# 22      08000362
# 23      04333009
# 24      08000471
# 25      07018312
# 26      04227210
# 27      04322132
# 28      04341970
# 29      04350311
#          ...
# 570     04249772
# 571     04966907
# 572     02003073
# 573     04997673
# 574     04975380
# 575     04217685
# 576     04830108
# 577     04963117
# 578     04435887
# 579     04456970
# 580     04784249
# 581     04353304
# 582     01005776
# 583     90159313
# 584     90206813
# 585     04996825
# 586     04700617
# 587     06002785
# 588     04993918
# 589     04796869
# 590     04092038
# ...

# %%
#病人ID
DF
# Out:
# array(['04234988', '04452761', '09000237', '04456923', '044436054',
#        '08000113', '07038328', '04271054', '07037321', '08000377',
#        '07040063', '04000079', '08001377', '08000221', '07033659',
#        '09000528', '08000597', '08000164', '09001193', '07044661',
#        '04367542', '08000282', '08000362', '04333009', '08000471',
#        '07018312', '04227210', '04322132', '04341970', '04350311',
#        '08000723', '04006952', '04348392', '04011151', '04138908',
#        '08000397', '04024351', '04338695', '07037946', '04012751',
#        '04331440', '04046977', '04340789', '04363148', '07032168',
#        '04115848', '04268583', '04261019', '04264653', '04021327',
#        '04199935', '04271323', '04260645', '08000251', '04098421',
#        '09000059', '04391056', '08000258', '07018888', '04223616',
#        '04023733', '04277620', '04332276', '04002204', '04262085',
#        '04310382', '04147404', '08001062', '08001009', '08001526',
# ...

# %%
# 9.1 表 病人主索引  PAT_MASTER_INDEX 预处理后
PAT_MASTER_INDEX = pd.read_csv('F:/data/input/病人主索引_预.tsv', sep='\t')

# %%
# 输出9.1表中患有高血压 疾病的人的信息（病人ID、性别、年龄）
PAT_MASTER_INDEX[PAT_MASTER_INDEX['PATIENT_ID'].isin(DF)]
# Out:
#         PATIENT_ID SEX DATE_OF_BIRTH
# 180       04000079   男     01-1月 -44
# 292       04004260   女     12-11月-37
# 415       08000597   男     01-9月 -28
# 836       08000471   男     01-3月 -26
# 1276      08000304   男     01-7月 -28
# 1312      08000362   男     01-5月 -28
# 1599      08000221   男     01-7月 -28
# 1954      08000593   男     01-1月 -29
# 1996      08000479   男     01-3月 -31
# 2554      08000164   男     01-4月 -26
# 2711      09000892   男     01-5月 -49
# 3162      08000113   男     01-7月 -31
# 3302      04002204   男     01-1月 -28
# 3575      09001089   女     01-11月-55
# 3882      09000192   男     15-8月 -33
# 3930      09000059   男     01-6月 -52
# 4847      08000397   男     02-2月 -27
# 4852      08000599   男     17-9月 -23
# 4862      08000603   男     01-11月-29
# 5414      09000848   男     01-2月 -47
# 5809      08000066   男     01-5月 -29
# 6098      09000828   女     01-10月-64
# 6239      08000251   男     25-9月 -19
# 6298      08001212   男     01-3月 -56
# ...

# %%
output_sex = PAT_MASTER_INDEX[PAT_MASTER_INDEX['PATIENT_ID'].isin(DF)]

# %%
#输出疾病1信息
output_sex.to_csv("F:/data/output/高血压1级_年龄_性别_信息.tsv")

# %%
# 9.4 表 诊断记录  预处理后
PAT_DATA = pd.read_csv('F:/data/input/就诊日期.tsv', sep='\t')

# %%
PAT_DATA
# Out:
#         PATIENT_ID DIAGNOSIS_DATE
# 0         08000598      07-6月 -00
# 1         08000598      17-6月 -00
# 2         08000279      10-6月 -00
# 3         08000279      10-6月 -00
# 4         08000279      10-6月 -00
# 5         08000279      10-6月 -00
# 6         08000279      10-6月 -00
# 7         08000279      10-6月 -00
# 8         04012492      25-7月 -00
# 9         06001257      29-6月 -00
# 10        06001257      29-6月 -00
# 11        06001257      29-6月 -00
# 12        06001257      29-6月 -00
# 13        06001257      29-6月 -00
# 14        06001257      29-6月 -00
# 15        06001257      29-6月 -00
# 16        04012492      25-7月 -00
# 17        04004716      25-7月 -00
# 18        07002615      04-6月 -00
# 19        07002615      04-6月 -00
# 20        07002615      04-6月 -00
# 21        04005889      16-6月 -00
# 22        04010327      30-6月 -00
# 23        04010327      30-6月 -00
# 24        04010327      30-6月 -00
# 25        04010327      30-6月 -00
# ...

# %%
DATA_count = PAT_DATA[PAT_DATA['PATIENT_ID'].isin(DF)]

# %%
DATA_count
# Out:
#         PATIENT_ID DIAGNOSIS_DATE
# 710       08000549      15-6月 -00
# 711       08000549      15-6月 -00
# 712       08000549      15-6月 -00
# 713       08000549      15-6月 -00
# 714       08000549      15-6月 -00
# 715       08000549      15-6月 -00
# 716       08000549      15-6月 -00
# 717       08000549      15-6月 -00
# 2115      08000377      30-3月 -00
# 2125      08000164      19-4月 -00
# 5158      08000282      11-5月 -00
# 5159      08000282      11-5月 -00
# 5160      08000282      11-5月 -00
# 5161      08000282      11-5月 -00
# 5162      08000304      25-5月 -00
# 5163      08000304      25-5月 -00
# 5164      08000304      25-5月 -00
# 5165      08000304      25-5月 -00
# 5166      08000304      25-5月 -00
# 5167      08000304      25-5月 -00
# 5168      08000304      25-5月 -00
# 5169      08000304      25-5月 -00
# 5170      08000304      25-5月 -00
# 5178      08000380      19-2月 -00
# 5179      08000380      19-2月 -00
# 5180      08000380      19-2月 -00
# ...

# %%
PAT_NO_SAME_1 = DATA_count.drop_duplicates(['PATIENT_ID'],'last')
PAT_NO_SAME_1
# Out:
#         PATIENT_ID DIAGNOSIS_DATE
# 297547    04276861      04-3月 -09
# 297719    04199935      01-11月-08
# 301694    04264653      03-11月-08
# 302339    04012544      31-1月 -09
# 312381    04340789      03-2月 -10
# 312849    08001009      09-3月 -10
# 314889    04046977      01-12月-09
# 316238    04012751      20-2月 -10
# 317365    07032168      08-3月 -10
# 318259    04331440      12-11月-09
# 318312    04332276      03-12月-09
# 320693    04138908      08-1月 -10
# 322076    04147404      11-10月-09
# 346597    04272374      13-1月 -09
# 349142    04348392      09-4月 -10
# 357281    04000079      14-10月-08
# 357795    04254996      13-8月 -08
# 373163    04341970      23-2月 -10
# 379664    04322132      08-10月-09
# 381152    04002204      12-9月 -09
# 384014    07033659      18-8月 -08
# 385573    07037321      21-8月 -08
# 388350    04252934      25-7月 -08
# 391270    08000925      07-9月 -08
# 393017    04310382      25-7月 -09
# 394061    08001526      16-7月 -09
# ...

# %%
PAT_NO_SAME_1.to_csv("F:/data/output/高血压1级_就诊日期_信息.tsv")

# %%
# 表4.1 疾病字典 DIAGNOSIS_DICT 
DIAGNOSIS_DICT = pd.read_csv('F:/data/input/诊断代码.tsv', sep='\t')

# %%
# 经检验 需要全部字段 此处重做 表9.7 诊断分类记录 DIAGNOSTIC_CATEGORY 预处理 得到病人ID和疾病ID
DIAGNOSTIC_CATEGORY = pd.read_csv('F:/data/input/诊断分类记录_全.tsv', sep='\t')
# Out:
# d:\programdata\anaconda3\envs\tensorflow\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (0,2) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
print(DIAGNOSTIC_CATEGORY)
# Out:
#         PATIENT_ID  VISIT_ID DIAGNOSIS_TYPE  DIAGNOSIS_NO    DIAGNOSIS_CODE  \
# 0         04003500         2              2             1           261  01
# 1         04003500         2              3             1           307.101
# 2         04003500         2              3             2           273.801
# 3         04003500         2              3             3           280  01
# 4         04010720         1              5             1           799.402
# 5         04010720         1              6             1           567.905
# 6         04007153         1              1             1  070.901+573.106*
# 7         04007153         1              2             1  070.901+573.106*
# 8         04007153         1              3             1           155.201
# 9         04017543         1              1             1           162.901
# 10        04017543         1              2             1           793.101
# ...

# %%
alist=['I25.101']
DIAGNOSTIC_CATEGORY[DIAGNOSTIC_CATEGORY['DIAGNOSIS_CODE'].isin(alist)]
# Out:
#         PATIENT_ID  VISIT_ID DIAGNOSIS_TYPE  DIAGNOSIS_NO DIAGNOSIS_CODE  \
# 240971    04230280        20              1             1        I25.101
# 240972    04230280        20              2             1        I25.101
# 240973    04230280        20              3             1        I25.101
# 241007    06000110         2              2             1        I25.101
# 241008    06000110         2              3             1        I25.101
# 241015    07056873         1              2             1        I25.101
# 241021    07056873         1              3             1        I25.101
# 241039    08000611        15              2             2        I25.101
# 241042    08000611        15              3             2        I25.101
# 241089    04415618         2              A             4        I25.101
# 241355    08000087        30              3             3        I25.101
# 241360    08000041        14              A             1        I25.101
# ...

# %%
#重定义
test = DIAGNOSTIC_CATEGORY[DIAGNOSTIC_CATEGORY['DIAGNOSIS_CODE'].isin(alist)]
#print(test)
#筛选出患病人数
DF = test['PATIENT_ID'].unique()   
#转格式
SS = Series(DF)
print(SS)
# Out:
# 0       04230280
# 1       06000110
# 2       07056873
# 3       08000611
# 4       04415618
# 5       08000087
# 6       08000041
# 7       04043054
# 8       04453304
# 9       04457844
# 10      04192288
# 11      04454174
# 12      04176872
# 13      04411099
# 14      04457799
# 15      04451110
# 16      04230295
# 17      04068254
# 18      04106429
# 19      04202307
# 20      04077673
# 21      04115848
# 22      08000304
# 23      04457360
# 24      04234988
# 25      04327447
# 26      06001302
# 27      04142605
# 28      04175271
# 29      04002377
#           ...
# 4858    04964659
# 4859    04228714
# 4860    04920357
# 4861    04985618
# 4862    04904035
# 4863    04993834
# 4864    02003407
# 4865    02002047
# 4866    04994516
# 4867    04962512
# 4868    04330774
# 4869    04995893
# 4870    04998425
# 4871    04956896
# 4872    04962234
# 4873    04944075
# 4874    90180893
# 4875    02000299
# 4876    02000674
# 4877     4030598
# 4878     4039717
# ...

# %%
# 经检验 需要全部字段 此处重做 表9.7 诊断分类记录 DIAGNOSTIC_CATEGORY 预处理 得到病人ID和疾病ID
DIAGNOSTIC_CATEGORY = pd.read_csv('F:/data/input/诊断分类记录_全.tsv', sep='\t')
# Out:
# d:\programdata\anaconda3\envs\tensorflow\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (0,2) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
print(DIAGNOSTIC_CATEGORY)
# Out:
#         PATIENT_ID  VISIT_ID DIAGNOSIS_TYPE  DIAGNOSIS_NO    DIAGNOSIS_CODE  \
# 0         04003500         2              2             1           261  01
# 1         04003500         2              3             1           307.101
# 2         04003500         2              3             2           273.801
# 3         04003500         2              3             3           280  01
# 4         04010720         1              5             1           799.402
# 5         04010720         1              6             1           567.905
# 6         04007153         1              1             1  070.901+573.106*
# 7         04007153         1              2             1  070.901+573.106*
# 8         04007153         1              3             1           155.201
# 9         04017543         1              1             1           162.901
# 10        04017543         1              2             1           793.101
# ...

# %%
# step1 I25.101(冠状动脉粥样硬化性心脏病)
alist=['I25.101']
DIAGNOSTIC_CATEGORY[DIAGNOSTIC_CATEGORY['DIAGNOSIS_CODE'].isin(alist)]
# Out:
#         PATIENT_ID  VISIT_ID DIAGNOSIS_TYPE  DIAGNOSIS_NO DIAGNOSIS_CODE  \
# 240971    04230280        20              1             1        I25.101
# 240972    04230280        20              2             1        I25.101
# 240973    04230280        20              3             1        I25.101
# 241007    06000110         2              2             1        I25.101
# 241008    06000110         2              3             1        I25.101
# 241015    07056873         1              2             1        I25.101
# 241021    07056873         1              3             1        I25.101
# 241039    08000611        15              2             2        I25.101
# 241042    08000611        15              3             2        I25.101
# 241089    04415618         2              A             4        I25.101
# 241355    08000087        30              3             3        I25.101
# 241360    08000041        14              A             1        I25.101
# ...

# %%
#重定义
test = DIAGNOSTIC_CATEGORY[DIAGNOSTIC_CATEGORY['DIAGNOSIS_CODE'].isin(alist)]
print(test)
# Out:
#         PATIENT_ID  VISIT_ID DIAGNOSIS_TYPE  DIAGNOSIS_NO DIAGNOSIS_CODE  \
# 240971    04230280        20              1             1        I25.101
# 240972    04230280        20              2             1        I25.101
# 240973    04230280        20              3             1        I25.101
# 241007    06000110         2              2             1        I25.101
# 241008    06000110         2              3             1        I25.101
# 241015    07056873         1              2             1        I25.101
# 241021    07056873         1              3             1        I25.101
# 241039    08000611        15              2             2        I25.101
# 241042    08000611        15              3             2        I25.101
# 241089    04415618         2              A             4        I25.101
# 241355    08000087        30              3             3        I25.101
# 241360    08000041        14              A             1        I25.101
# ...

# %%
#筛选出频率第一疾病的实际患病人数 4888人
DF = test['PATIENT_ID'].unique()   
#转格式
SS = Series(DF)
SS
# Out:
# 0       04230280
# 1       06000110
# 2       07056873
# 3       08000611
# 4       04415618
# 5       08000087
# 6       08000041
# 7       04043054
# 8       04453304
# 9       04457844
# 10      04192288
# 11      04454174
# 12      04176872
# 13      04411099
# 14      04457799
# 15      04451110
# 16      04230295
# 17      04068254
# 18      04106429
# 19      04202307
# 20      04077673
# 21      04115848
# 22      08000304
# 23      04457360
# 24      04234988
# 25      04327447
# 26      06001302
# 27      04142605
# 28      04175271
# 29      04002377
#           ...
# 4858    04964659
# 4859    04228714
# 4860    04920357
# 4861    04985618
# 4862    04904035
# 4863    04993834
# 4864    02003407
# 4865    02002047
# 4866    04994516
# 4867    04962512
# 4868    04330774
# 4869    04995893
# 4870    04998425
# 4871    04956896
# 4872    04962234
# 4873    04944075
# 4874    90180893
# 4875    02000299
# 4876    02000674
# 4877     4030598
# 4878     4039717
# ...

# %%
#病人ID
DF
# Out:
# array(['04230280', '06000110', '07056873', ..., 4394714, 4946613, 4043054],
#       dtype=object)

# %%
# 9.4 表 诊断记录  预处理后
PAT_DATA = pd.read_csv('F:/data/input/就诊日期.tsv', sep='\t')

# %%
PAT_DATA
# Out:
#         PATIENT_ID DIAGNOSIS_DATE
# 0         08000598      07-6月 -00
# 1         08000598      17-6月 -00
# 2         08000279      10-6月 -00
# 3         08000279      10-6月 -00
# 4         08000279      10-6月 -00
# 5         08000279      10-6月 -00
# 6         08000279      10-6月 -00
# 7         08000279      10-6月 -00
# 8         04012492      25-7月 -00
# 9         06001257      29-6月 -00
# 10        06001257      29-6月 -00
# 11        06001257      29-6月 -00
# 12        06001257      29-6月 -00
# 13        06001257      29-6月 -00
# 14        06001257      29-6月 -00
# 15        06001257      29-6月 -00
# 16        04012492      25-7月 -00
# 17        04004716      25-7月 -00
# 18        07002615      04-6月 -00
# 19        07002615      04-6月 -00
# 20        07002615      04-6月 -00
# 21        04005889      16-6月 -00
# 22        04010327      30-6月 -00
# 23        04010327      30-6月 -00
# 24        04010327      30-6月 -00
# 25        04010327      30-6月 -00
# ...

# %%
DATA_count = PAT_DATA[PAT_DATA['PATIENT_ID'].isin(DF)]

# %%
DATA_count
# Out:
#         PATIENT_ID DIAGNOSIS_DATE
# 0         08000598      07-6月 -00
# 1         08000598      17-6月 -00
# 139       04008472      30-6月 -00
# 140       04008472      30-6月 -00
# 157       06000797      30-4月 -00
# 158       06000797      30-4月 -00
# 159       06000797      30-4月 -00
# 160       06000797      30-4月 -00
# 161       06000797      30-4月 -00
# 162       06000797      30-4月 -00
# 172       04008741      23-5月 -00
# 174       04008741      23-5月 -00
# 175       04008741      23-5月 -00
# 299       08000550      11-5月 -00
# 300       08000550      11-5月 -00
# 301       08000550      11-5月 -00
# 376       09000110      25-5月 -00
# 377       09000110      25-5月 -00
# 378       09000110      25-5月 -00
# 379       09000110      25-5月 -00
# 380       09000110      25-5月 -00
# 388       04032188      24-5月 -00
# 389       04032188      24-5月 -00
# 390       04032188      24-5月 -00
# 391       04032188      24-5月 -00
# 392       04032188      24-5月 -00
# ...

# %%
PAT_NO_SAME_1 = DATA_count.drop_duplicates(['PATIENT_ID'],'last')
PAT_NO_SAME_1
# Out:
#         PATIENT_ID DIAGNOSIS_DATE
# 288239    04010670      06-9月 -10
# 288332    04372346      12-9月 -10
# 289280    04083884      02-10月-10
# 289741    08001727      21-10月-10
# 290005    04020394      30-9月 -10
# 290804    04022113      23-10月-10
# 291113    04329259      02-11月-10
# 291469    04383215      14-9月 -10
# 291490    04024336      27-8月 -10
# 291597    08001725      14-9月 -10
# 291672    04389456      07-10月-10
# 292205    04222849      28-9月 -10
# 292340    08001353      26-9月 -10
# 293275    04014986      14-9月 -10
# 293990    04169768      11-10月-10
# 293994    04370273      25-10月-10
# 294194    04091511      25-8月 -10
# 294423    04381977      06-9月 -10
# 294848    04278977      19-3月 -09
# 295190    04142199      18-11月-08
# 295575    04112058      25-11月-08
# 295758    04275193      07-2月 -09
# 296057    04050882      26-11月-08
# 296416    04275066      09-2月 -09
# 296929    04277023      26-2月 -09
# 297144    04270289      23-12月-08
# ...

# %%
PAT_NO_SAME_1.to_csv("F:/data/output/心1_就诊日期_信息.tsv")

# %%
# 表4.1 疾病字典 DIAGNOSIS_DICT 
DIAGNOSIS_DICT = pd.read_csv('F:/data/input/诊断代码.tsv', sep='\t')

# %%
# 经检验 需要全部字段 此处重做 表9.7 诊断分类记录 DIAGNOSTIC_CATEGORY 预处理 得到病人ID和疾病ID
DIAGNOSTIC_CATEGORY = pd.read_csv('F:/data/input/诊断分类记录_全.tsv', sep='\t')
# Out:
# d:\programdata\anaconda3\envs\tensorflow\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (0,2) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
print(DIAGNOSTIC_CATEGORY)
# Out:
#         PATIENT_ID  VISIT_ID DIAGNOSIS_TYPE  DIAGNOSIS_NO    DIAGNOSIS_CODE  \
# 0         04003500         2              2             1           261  01
# 1         04003500         2              3             1           307.101
# 2         04003500         2              3             2           273.801
# 3         04003500         2              3             3           280  01
# 4         04010720         1              5             1           799.402
# 5         04010720         1              6             1           567.905
# 6         04007153         1              1             1  070.901+573.106*
# 7         04007153         1              2             1  070.901+573.106*
# 8         04007153         1              3             1           155.201
# 9         04017543         1              1             1           162.901
# 10        04017543         1              2             1           793.101
# ...

# %%
#step2 I49.901(心律失常)
alist=['I49.901']
DIAGNOSTIC_CATEGORY[DIAGNOSTIC_CATEGORY['DIAGNOSIS_CODE'].isin(alist)]
# Out:
#         PATIENT_ID  VISIT_ID DIAGNOSIS_TYPE  DIAGNOSIS_NO DIAGNOSIS_CODE  \
# 241106    04451590         1              3             3        I49.901
# 241217    04451769         1              A             2        I49.901
# 241221    06003511        11              A             3        I49.901
# 241279    04222659         4              2             3        I49.901
# 241339    04222659         4              A             2        I49.901
# 241554    04457844         1              3             4        I49.901
# 241560    04192288         3              A             1        I49.901
# 241669    07030087         6              2             1        I49.901
# 241670    07030087         6              3             1        I49.901
# 241673    07030087         5              1             1        I49.901
# 241674    07030087         5              2             1        I49.901
# 241677    07030087         5              3             1        I49.901
# ...

# %%
#重定义
test = DIAGNOSTIC_CATEGORY[DIAGNOSTIC_CATEGORY['DIAGNOSIS_CODE'].isin(alist)]
print(test)
# Out:
#         PATIENT_ID  VISIT_ID DIAGNOSIS_TYPE  DIAGNOSIS_NO DIAGNOSIS_CODE  \
# 241106    04451590         1              3             3        I49.901
# 241217    04451769         1              A             2        I49.901
# 241221    06003511        11              A             3        I49.901
# 241279    04222659         4              2             3        I49.901
# 241339    04222659         4              A             2        I49.901
# 241554    04457844         1              3             4        I49.901
# 241560    04192288         3              A             1        I49.901
# 241669    07030087         6              2             1        I49.901
# 241670    07030087         6              3             1        I49.901
# 241673    07030087         5              1             1        I49.901
# 241674    07030087         5              2             1        I49.901
# 241677    07030087         5              3             1        I49.901
# ...

# %%
#筛选出频率第一疾病的实际患病人数 9130人
DF = test['PATIENT_ID'].unique()   
#转格式
SS = Series(DF)
SS
# Out:
# 0       04451590
# 1       04451769
# 2       06003511
# 3       04222659
# 4       04457844
# 5       04192288
# 6       07030087
# 7       04284506
# 8       04131836
# 9       04230295
# 10      04202307
# 11      04234988
# 12      04230280
# 13      04465957
# 14      04142605
# 15      04444357
# 16      04008747
# 17      04451601
# 18      04154512
# 19      04189463
# 20      04105953
# 21      04458135
# 22      04261226
# 23      04452292
# 24      04106993
# 25      04015521
# 26      04448266
# 27      04331933
# 28      04359543
# 29      04068446
#           ...
# 2211    04584842
# 2212    04997345
# 2213    04188448
# 2214    90211033
# 2215    04938368
# 2216    04255093
# 2217    04079699
# 2218    04376573
# 2219    04890394
# 2220    04997015
# 2221    04980284
# 2222    04880915
# 2223    04423148
# 2224    04998177
# 2225    04996040
# 2226    04328825
# 2227    04072209
# 2228    04987587
# 2229    04124723
# 2230    04985618
# 2231    04993834
# ...

# %%
#病人ID
DF
# Out:
# array(['04451590', '04451769', '06003511', ..., '04751774', '04981783',
#        4387913], dtype=object)

# %%
# 9.4 表 诊断记录  预处理后
PAT_DATA = pd.read_csv('F:/data/input/年龄和疾病的关系数据集/就诊日期.tsv', sep='\t')

# %%
PAT_DATA
# Out:
#         PATIENT_ID DIAGNOSIS_DATE
# 0         08000598      07-6月 -00
# 1         08000598      17-6月 -00
# 2         08000279      10-6月 -00
# 3         08000279      10-6月 -00
# 4         08000279      10-6月 -00
# 5         08000279      10-6月 -00
# 6         08000279      10-6月 -00
# 7         08000279      10-6月 -00
# 8         04012492      25-7月 -00
# 9         06001257      29-6月 -00
# 10        06001257      29-6月 -00
# 11        06001257      29-6月 -00
# 12        06001257      29-6月 -00
# 13        06001257      29-6月 -00
# 14        06001257      29-6月 -00
# 15        06001257      29-6月 -00
# 16        04012492      25-7月 -00
# 17        04004716      25-7月 -00
# 18        07002615      04-6月 -00
# 19        07002615      04-6月 -00
# 20        07002615      04-6月 -00
# 21        04005889      16-6月 -00
# 22        04010327      30-6月 -00
# 23        04010327      30-6月 -00
# 24        04010327      30-6月 -00
# 25        04010327      30-6月 -00
# ...

# %%
DATA_count = PAT_DATA[PAT_DATA['PATIENT_ID'].isin(DF)]

DATA_count
# Out:
#         PATIENT_ID DIAGNOSIS_DATE
# 0         08000598      07-6月 -00
# 1         08000598      17-6月 -00
# 157       06000797      30-4月 -00
# 158       06000797      30-4月 -00
# 159       06000797      30-4月 -00
# 160       06000797      30-4月 -00
# 161       06000797      30-4月 -00
# 162       06000797      30-4月 -00
# 388       04032188      24-5月 -00
# 389       04032188      24-5月 -00
# 390       04032188      24-5月 -00
# 391       04032188      24-5月 -00
# 392       04032188      24-5月 -00
# 540       04032188      09-6月 -00
# 544       04032188      09-6月 -00
# 552       04032188      09-6月 -00
# 555       04032188      09-6月 -00
# 562       04032188      09-6月 -00
# 749       04000808      11-4月 -00
# 863       04001747      17-4月 -00
# 864       06000797      17-4月 -00
# 1291      04004656      14-5月 -00
# 1292      04004656      14-5月 -00
# 1293      04004656      14-5月 -00
# 1294      04004656      14-5月 -00
# 1295      04004656      14-5月 -00
# ...

# %%
PAT_NO_SAME_1 = DATA_count.drop_duplicates(['PATIENT_ID'],'last')
PAT_NO_SAME_1
# Out:
#         PATIENT_ID DIAGNOSIS_DATE
# 289268    04388436      30-9月 -10
# 289280    04083884      02-10月-10
# 290005    04020394      30-9月 -10
# 290032    04293011      09-10月-10
# 291113    04329259      02-11月-10
# 291279    04164974      30-8月 -10
# 292816    04394400      24-10月-10
# 293990    04169768      11-10月-10
# 293994    04370273      25-10月-10
# 294182    04380033      01-9月 -10
# 294186    04376480      10-8月 -10
# 294848    04278977      19-3月 -09
# 296436    04275338      10-2月 -09
# 297266    04042322      29-10月-08
# 297295    04251321      21-10月-08
# 297303    04147295      04-11月-08
# 298813    04179802      06-12月-08
# 300267    04216846      02-2月 -09
# 300739    04087224      20-2月 -09
# 303676    07017079      13-7月 -09
# 303981    04096970      13-5月 -09
# 304812    07045655      23-6月 -09
# 304844    04096319      09-6月 -09
# 306186    04309135      18-7月 -09
# 306576    04209194      13-6月 -09
# 307022    04290930      03-6月 -09
# ...

# %%
PAT_NO_SAME_1.to_csv("F:/data/output/心2_就诊日期_信息.tsv")

# %%
# 经检验 需要全部字段 此处重做 表9.7 诊断分类记录 DIAGNOSTIC_CATEGORY 预处理 得到病人ID和疾病ID
DIAGNOSTIC_CATEGORY = pd.read_csv('F:/data/input/诊断分类记录_全.tsv', sep='\t')  
print(DIAGNOSTIC_CATEGORY)
# Out:
#         PATIENT_ID  VISIT_ID DIAGNOSIS_TYPE  DIAGNOSIS_NO    DIAGNOSIS_CODE  \
# 0         04003500         2              2             1           261  01
# 1         04003500         2              3             1           307.101
# 2         04003500         2              3             2           273.801
# 3         04003500         2              3             3           280  01
# 4         04010720         1              5             1           799.402
# 5         04010720         1              6             1           567.905
# 6         04007153         1              1             1  070.901+573.106*
# 7         04007153         1              2             1  070.901+573.106*
# 8         04007153         1              3             1           155.201
# 9         04017543         1              1             1           162.901
# 10        04017543         1              2             1           793.101
# ...

# %%
#step3 I50.904(心功能不全)
alist=['I50.904']
DIAGNOSTIC_CATEGORY[DIAGNOSTIC_CATEGORY['DIAGNOSIS_CODE'].isin(alist)]
# Out:
#         PATIENT_ID  VISIT_ID DIAGNOSIS_TYPE  DIAGNOSIS_NO DIAGNOSIS_CODE  \
# 241168    04272961         2              A             4        I50.904
# 241460    04001354         3              2             3        I50.904
# 241463    04001354         3              3             3        I50.904
# 241946    04077673        13              A             3        I50.904
# 242238    04457360         1              2             4        I50.904
# 242315    04061110         7              2             2        I50.904
# 242317    04061110         7              3             2        I50.904
# 242685    04457360         1              A             3        I50.904
# 245399    04135726         1              A             4        I50.904
# 247381    04421323         3              2             3        I50.904
# 247384    04421323         3              A             2        I50.904
# 249933    04459150         1              A             1        I50.904
# ...

# %%
#重定义
test = DIAGNOSTIC_CATEGORY[DIAGNOSTIC_CATEGORY['DIAGNOSIS_CODE'].isin(alist)]
print(test)
# Out:
#         PATIENT_ID  VISIT_ID DIAGNOSIS_TYPE  DIAGNOSIS_NO DIAGNOSIS_CODE  \
# 241168    04272961         2              A             4        I50.904
# 241460    04001354         3              2             3        I50.904
# 241463    04001354         3              3             3        I50.904
# 241946    04077673        13              A             3        I50.904
# 242238    04457360         1              2             4        I50.904
# 242315    04061110         7              2             2        I50.904
# 242317    04061110         7              3             2        I50.904
# 242685    04457360         1              A             3        I50.904
# 245399    04135726         1              A             4        I50.904
# 247381    04421323         3              2             3        I50.904
# 247384    04421323         3              A             2        I50.904
# 249933    04459150         1              A             1        I50.904
# ...

# %%
#筛选出频率第一疾病的实际患病人数 9130人
DF = test['PATIENT_ID'].unique()   
#转格式
SS = Series(DF)
SS
# Out:
# 0       04272961
# 1       04001354
# 2       04077673
# 3       04457360
# 4       04061110
# 5       04135726
# 6       04421323
# 7       04459150
# 8       04256301
# 9       04437648
# 10      04215504
# 11      04043329
# 12      04456132
# 13      08000123
# 14      04226024
# 15      04251191
# 16      04256422
# 17      04038940
# 18      04180134
# 19      04046677
# 20      04012365
# 21      04251244
# 22      04255076
# 23      04255711
# 24      04267606
# 25      04206666
# 26      04258127
# 27      04257109
# 28      04261069
# 29      04205305
#           ...
# 1680    04202384
# 1681    04922631
# 1682    04996699
# 1683    04446786
# 1684    04802412
# 1685    04996276
# 1686    04996040
# 1687    04991790
# 1688    04998517
# 1689    04069566
# 1690    04714651
# 1691    04941588
# 1692    04981326
# 1693    04984320
# 1694    04983047
# 1695    04503647
# 1696    04029213
# 1697    04959616
# 1698    02003407
# 1699    04985739
# 1700    04048197
# ...

# %%
#病人ID
DF
# Out:
# array(['04272961', '04001354', '04077673', ..., 4911846, 4909795, 4394714],
#       dtype=object)

# %%
# 9.4 表 诊断记录  预处理后
PAT_DATA = pd.read_csv('F:/data/input/就诊日期.tsv', sep='\t')
PAT_DATA
# Out:
#         PATIENT_ID DIAGNOSIS_DATE
# 0         08000598      07-6月 -00
# 1         08000598      17-6月 -00
# 2         08000279      10-6月 -00
# 3         08000279      10-6月 -00
# 4         08000279      10-6月 -00
# 5         08000279      10-6月 -00
# 6         08000279      10-6月 -00
# 7         08000279      10-6月 -00
# 8         04012492      25-7月 -00
# 9         06001257      29-6月 -00
# 10        06001257      29-6月 -00
# 11        06001257      29-6月 -00
# 12        06001257      29-6月 -00
# 13        06001257      29-6月 -00
# 14        06001257      29-6月 -00
# 15        06001257      29-6月 -00
# 16        04012492      25-7月 -00
# 17        04004716      25-7月 -00
# 18        07002615      04-6月 -00
# 19        07002615      04-6月 -00
# 20        07002615      04-6月 -00
# 21        04005889      16-6月 -00
# 22        04010327      30-6月 -00
# 23        04010327      30-6月 -00
# 24        04010327      30-6月 -00
# 25        04010327      30-6月 -00
# ...

# %%
DATA_count = PAT_DATA[PAT_DATA['PATIENT_ID'].isin(DF)]
DATA_count
# Out:
#         PATIENT_ID DIAGNOSIS_DATE
# 0         08000598      07-6月 -00
# 1         08000598      17-6月 -00
# 157       06000797      30-4月 -00
# 158       06000797      30-4月 -00
# 159       06000797      30-4月 -00
# 160       06000797      30-4月 -00
# 161       06000797      30-4月 -00
# 162       06000797      30-4月 -00
# 172       04008741      23-5月 -00
# 174       04008741      23-5月 -00
# 175       04008741      23-5月 -00
# 299       08000550      11-5月 -00
# 300       08000550      11-5月 -00
# 301       08000550      11-5月 -00
# 316       04005269      05-6月 -00
# 317       04005269      05-6月 -00
# 318       04005269      05-6月 -00
# 319       04005269      05-6月 -00
# 320       04005269      05-6月 -00
# 388       04032188      24-5月 -00
# 389       04032188      24-5月 -00
# 390       04032188      24-5月 -00
# 391       04032188      24-5月 -00
# 392       04032188      24-5月 -00
# 540       04032188      09-6月 -00
# 544       04032188      09-6月 -00
# ...

# %%
PAT_NO_SAME_1 = DATA_count.drop_duplicates(['PATIENT_ID'],'last')
PAT_NO_SAME_1
# Out:
#         PATIENT_ID DIAGNOSIS_DATE
# 289268    04388436      30-9月 -10
# 290032    04293011      09-10月-10
# 291469    04383215      14-9月 -10
# 294423    04381977      06-9月 -10
# 294848    04278977      19-3月 -09
# 298419    04152469      05-12月-08
# 298904    04206666      07-12月-08
# 304758    04083275      04-8月 -09
# 304844    04096319      09-6月 -09
# 305657    04315649      30-8月 -09
# 307388    04320873      12-9月 -09
# 308578    04274386      23-1月 -09
# 312889    04332315      23-1月 -10
# 315784    04337716      02-3月 -10
# 319352    04196058      18-12月-09
# 319950    04322241      01-10月-09
# 320112    04334667      04-1月 -10
# 320717    04296057      10-3月 -10
# 321631    04315543      29-9月 -09
# 321805    04334756      16-12月-09
# 322468    04337987      14-1月 -10
# 322713    04311124      19-10月-09
# 322849    04003268      04-3月 -10
# 323689    04318828      25-9月 -09
# 325468    04162080      03-10月-09
# 339774    04274457      29-1月 -09
# ...

# %%
PAT_NO_SAME_1.to_csv("F:/data/output心3_就诊日期_信息.tsv")

# %%
# 经检验 需要全部字段 此处重做 表9.7 诊断分类记录 DIAGNOSTIC_CATEGORY 预处理 得到病人ID和疾病ID
DIAGNOSTIC_CATEGORY = pd.read_csv('F:/data/input/诊断分类记录_全.tsv', sep='\t')  
print(DIAGNOSTIC_CATEGORY)
# Out:
#         PATIENT_ID  VISIT_ID DIAGNOSIS_TYPE  DIAGNOSIS_NO    DIAGNOSIS_CODE  \
# 0         04003500         2              2             1           261  01
# 1         04003500         2              3             1           307.101
# 2         04003500         2              3             2           273.801
# 3         04003500         2              3             3           280  01
# 4         04010720         1              5             1           799.402
# 5         04010720         1              6             1           567.905
# 6         04007153         1              1             1  070.901+573.106*
# 7         04007153         1              2             1  070.901+573.106*
# 8         04007153         1              3             1           155.201
# 9         04017543         1              1             1           162.901
# 10        04017543         1              2             1           793.101
# ...

# %%
#step4 I48  04(心房纤维性颤动)
alist=['I48  04']
DIAGNOSTIC_CATEGORY[DIAGNOSTIC_CATEGORY['DIAGNOSIS_CODE'].isin(alist)]
# Out:
#         PATIENT_ID  VISIT_ID DIAGNOSIS_TYPE  DIAGNOSIS_NO DIAGNOSIS_CODE  \
# 241107    04451590         1              3             4        I48  04
# 241711    04131836         8              3             5        I48  04
# 241851    04068254         2              A             2        I48  04
# 241877    04460009         1              2             2        I48  04
# 241881    04460009         1              3             2        I48  04
# 241960    04115848         7              A             2        I48  04
# 242413    04462284         1              A             1        I48  04
# 243277    04453366         2              A             1        I48  04
# 243425    04008747        13              A             2        I48  04
# 243664    04453366         1              A             1        I48  04
# 243694    04457536         1              A             2        I48  04
# 244294    06003511        12              A             2        I48  04
# ...

# %%
#重定义
test = DIAGNOSTIC_CATEGORY[DIAGNOSTIC_CATEGORY['DIAGNOSIS_CODE'].isin(alist)]
print(test)
# Out:
#         PATIENT_ID  VISIT_ID DIAGNOSIS_TYPE  DIAGNOSIS_NO DIAGNOSIS_CODE  \
# 241107    04451590         1              3             4        I48  04
# 241711    04131836         8              3             5        I48  04
# 241851    04068254         2              A             2        I48  04
# 241877    04460009         1              2             2        I48  04
# 241881    04460009         1              3             2        I48  04
# 241960    04115848         7              A             2        I48  04
# 242413    04462284         1              A             1        I48  04
# 243277    04453366         2              A             1        I48  04
# 243425    04008747        13              A             2        I48  04
# 243664    04453366         1              A             1        I48  04
# 243694    04457536         1              A             2        I48  04
# 244294    06003511        12              A             2        I48  04
# ...

# %%
#筛选出频率第一疾病的实际患病人数 9130人
DF = test['PATIENT_ID'].unique()   
#转格式
SS = Series(DF)
SS
# Out:
# 0       04451590
# 1       04131836
# 2       04068254
# 3       04460009
# 4       04115848
# 5       04462284
# 6       04453366
# 7       04008747
# 8       04457536
# 9       06003511
# 10      04083333
# 11      04182613
# 12      04448112
# 13      04428030
# 14      04246896
# 15      04043236
# 16      04256301
# 17      04005939
# 18      04076417
# 19      04202307
# 20      04000997
# 21      04124426
# 22      04236830
# 23      04259295
# 24      04085780
# 25      04226459
# 26      04125429
# 27      04015121
# 28      04079346
# 29      04233998
#           ...
# 1294    04124723
# 1295    04139829
# 1296    04753870
# 1297    04996599
# 1298    04990398
# 1299    04223705
# 1300    04887982
# 1301    04917403
# 1302    04972142
# 1303    04491719
# 1304    04906080
# 1305    04910000
# 1306    04606825
# 1307    04996030
# 1308    04894291
# 1309    04604355
# 1310    04356423
# 1311    04999817
# 1312    04416134
# 1313    04984320
# 1314    04964658
# ...

# %%
#病人ID
DF
# Out:
# array(['04451590', '04131836', '04068254', ..., '04962234', '90180893',
#        4549879], dtype=object)

# %%
# 9.4 表 诊断记录  预处理后
PAT_DATA = pd.read_csv('F:/data/input/就诊日期.tsv', sep='\t')
PAT_DATA
# Out:
#         PATIENT_ID DIAGNOSIS_DATE
# 0         08000598      07-6月 -00
# 1         08000598      17-6月 -00
# 2         08000279      10-6月 -00
# 3         08000279      10-6月 -00
# 4         08000279      10-6月 -00
# 5         08000279      10-6月 -00
# 6         08000279      10-6月 -00
# 7         08000279      10-6月 -00
# 8         04012492      25-7月 -00
# 9         06001257      29-6月 -00
# 10        06001257      29-6月 -00
# 11        06001257      29-6月 -00
# 12        06001257      29-6月 -00
# 13        06001257      29-6月 -00
# 14        06001257      29-6月 -00
# 15        06001257      29-6月 -00
# 16        04012492      25-7月 -00
# 17        04004716      25-7月 -00
# 18        07002615      04-6月 -00
# 19        07002615      04-6月 -00
# 20        07002615      04-6月 -00
# 21        04005889      16-6月 -00
# 22        04010327      30-6月 -00
# 23        04010327      30-6月 -00
# 24        04010327      30-6月 -00
# 25        04010327      30-6月 -00
# ...

# %%
DATA_count = PAT_DATA[PAT_DATA['PATIENT_ID'].isin(DF)]
DATA_count
# Out:
#         PATIENT_ID DIAGNOSIS_DATE
# 316       04005269      05-6月 -00
# 317       04005269      05-6月 -00
# 318       04005269      05-6月 -00
# 319       04005269      05-6月 -00
# 320       04005269      05-6月 -00
# 388       04032188      24-5月 -00
# 389       04032188      24-5月 -00
# 390       04032188      24-5月 -00
# 391       04032188      24-5月 -00
# 392       04032188      24-5月 -00
# 540       04032188      09-6月 -00
# 544       04032188      09-6月 -00
# 552       04032188      09-6月 -00
# 555       04032188      09-6月 -00
# 562       04032188      09-6月 -00
# 749       04000808      11-4月 -00
# 1291      04004656      14-5月 -00
# 1292      04004656      14-5月 -00
# 1293      04004656      14-5月 -00
# 1294      04004656      14-5月 -00
# 1295      04004656      14-5月 -00
# 1296      04004656      14-5月 -00
# 1297      04004656      14-5月 -00
# 1559      08000591      12-4月 -00
# 1560      08000591      12-4月 -00
# 1561      08000591      12-4月 -00
# ...

# %%
PAT_NO_SAME_1 = DATA_count.drop_duplicates(['PATIENT_ID'],'last')
PAT_NO_SAME_1
# Out:
#         PATIENT_ID DIAGNOSIS_DATE
# 291490    04024336      27-8月 -10
# 292502    04389379      22-10月-10
# 294182    04380033      01-9月 -10
# 294186    04376480      10-8月 -10
# 297047    04088652      04-3月 -09
# 298904    04206666      07-12月-08
# 301590    04170575      30-12月-08
# 302339    04012544      31-1月 -09
# 303480    04285147      21-4月 -09
# 304575    04000485      27-7月 -09
# 308793    04290929      05-6月 -09
# 315784    04337716      02-3月 -10
# 316121    04334291      06-12月-09
# 316298    04332865      14-12月-09
# 317280    04330691      08-12月-09
# 319002    04266091      05-3月 -10
# 319909    04316797      07-12月-09
# 319950    04322241      01-10月-09
# 320112    04334667      04-1月 -10
# 321631    04315543      29-9月 -09
# 321760    04218912      16-2月 -09
# 321814    04329645      19-11月-09
# 323245    04283778      07-9月 -09
# 324104    04081177      04-11月-09
# 327147    04260400      02-9月 -09
# 339648    08000607      26-3月 -09
# ...

# %%
PAT_NO_SAME_1.to_csv("F:/data/output/心4_就诊日期_信息.tsv")

# %%
# 经检验 需要全部字段 此处重做 表9.7 诊断分类记录 DIAGNOSTIC_CATEGORY 预处理 得到病人ID和疾病ID
DIAGNOSTIC_CATEGORY = pd.read_csv('F:/data/input/诊断分类记录_全.tsv', sep='\t')  
print(DIAGNOSTIC_CATEGORY)
# Out:
#         PATIENT_ID  VISIT_ID DIAGNOSIS_TYPE  DIAGNOSIS_NO    DIAGNOSIS_CODE  \
# 0         04003500         2              2             1           261  01
# 1         04003500         2              3             1           307.101
# 2         04003500         2              3             2           273.801
# 3         04003500         2              3             3           280  01
# 4         04010720         1              5             1           799.402
# 5         04010720         1              6             1           567.905
# 6         04007153         1              1             1  070.901+573.106*
# 7         04007153         1              2             1  070.901+573.106*
# 8         04007153         1              3             1           155.201
# 9         04017543         1              1             1           162.901
# 10        04017543         1              2             1           793.101
# ...

# %%
# step5 I11.901(高血压性心脏病)
alist=['I11.901']
DIAGNOSTIC_CATEGORY[DIAGNOSTIC_CATEGORY['DIAGNOSIS_CODE'].isin(alist)]
# Out:
#         PATIENT_ID  VISIT_ID DIAGNOSIS_TYPE  DIAGNOSIS_NO DIAGNOSIS_CODE  \
# 241087    04415618         2              A             2        I11.901
# 241098    04282667         1              2             3        I11.901
# 241101    04282667         1              3             3        I11.901
# 241220    06003511        11              A             2        I11.901
# 241573    04176872         1              A             3        I11.901
# 241709    04131836         8              3             3        I11.901
# 241721    04457799         1              A             1        I11.901
# 241843    04230295         1              A             1        I11.901
# 241892    04106429         8              A             1        I11.901
# 241934    04077673        13              A             1        I11.901
# 244293    06003511        12              A             1        I11.901
# 244703    04154512         4              A             3        I11.901
# ...

# %%
#重定义
test = DIAGNOSTIC_CATEGORY[DIAGNOSTIC_CATEGORY['DIAGNOSIS_CODE'].isin(alist)]
print(test)
# Out:
#         PATIENT_ID  VISIT_ID DIAGNOSIS_TYPE  DIAGNOSIS_NO DIAGNOSIS_CODE  \
# 241087    04415618         2              A             2        I11.901
# 241098    04282667         1              2             3        I11.901
# 241101    04282667         1              3             3        I11.901
# 241220    06003511        11              A             2        I11.901
# 241573    04176872         1              A             3        I11.901
# 241709    04131836         8              3             3        I11.901
# 241721    04457799         1              A             1        I11.901
# 241843    04230295         1              A             1        I11.901
# 241892    04106429         8              A             1        I11.901
# 241934    04077673        13              A             1        I11.901
# 244293    06003511        12              A             1        I11.901
# 244703    04154512         4              A             3        I11.901
# ...

# %%
#筛选出频率第一疾病的实际患病人数 9130人
DF = test['PATIENT_ID'].unique()   
#转格式
SS = Series(DF)
SS
# Out:
# 0       04415618
# 1       04282667
# 2       06003511
# 3       04176872
# 4       04131836
# 5       04457799
# 6       04230295
# 7       04106429
# 8       04077673
# 9       04154512
# 10      04189463
# 11      04478232
# 12      04204569
# 13      04106993
# 14      06001260
# 15      04073244
# 16      04127575
# 17      04180808
# 18      06000283
# 19      04008483
# 20      04182613
# 21      04461614
# 22      04461655
# 23      04028749
# 24      04452286
# 25      04453264
# 26      04013598
# 27      04459150
# 28      04461735
# 29      04043329
#           ...
# 971     04230574
# 972     04983278
# 973     04039109
# 974     04886198
# 975     04982173
# 976     04376981
# 977     04170693
# 978     04954362
# 979     04896745
# 980     04980376
# 981     04394038
# 982     04123277
# 983     04996599
# 984     04643119
# 985     01005776
# 986     04618732
# 987     04808763
# 988     04994682
# 989     04997015
# 990     04996276
# 991     04953781
# ...

# %%
#病人ID
DF
# Out:
# array(['04415618', '04282667', '06003511', ..., '04957606', 4981737,
#        4911846], dtype=object)

# %%
# 9.4 表 诊断记录  预处理后
PAT_DATA = pd.read_csv('F:/data/input/就诊日期.tsv', sep='\t')
PAT_DATA
# Out:
#         PATIENT_ID DIAGNOSIS_DATE
# 0         08000598      07-6月 -00
# 1         08000598      17-6月 -00
# 2         08000279      10-6月 -00
# 3         08000279      10-6月 -00
# 4         08000279      10-6月 -00
# 5         08000279      10-6月 -00
# 6         08000279      10-6月 -00
# 7         08000279      10-6月 -00
# 8         04012492      25-7月 -00
# 9         06001257      29-6月 -00
# 10        06001257      29-6月 -00
# 11        06001257      29-6月 -00
# 12        06001257      29-6月 -00
# 13        06001257      29-6月 -00
# 14        06001257      29-6月 -00
# 15        06001257      29-6月 -00
# 16        04012492      25-7月 -00
# 17        04004716      25-7月 -00
# 18        07002615      04-6月 -00
# 19        07002615      04-6月 -00
# 20        07002615      04-6月 -00
# 21        04005889      16-6月 -00
# 22        04010327      30-6月 -00
# 23        04010327      30-6月 -00
# 24        04010327      30-6月 -00
# 25        04010327      30-6月 -00
# ...

# %%
DATA_count = PAT_DATA[PAT_DATA['PATIENT_ID'].isin(DF)]
DATA_count
# Out:
#         PATIENT_ID DIAGNOSIS_DATE
# 139       04008472      30-6月 -00
# 140       04008472      30-6月 -00
# 452       04008472      22-5月 -00
# 454       04008472      22-5月 -00
# 459       04008472      22-5月 -00
# 749       04000808      11-4月 -00
# 1073      04003669      17-7月 -00
# 1074      04003669      17-7月 -00
# 1075      04003669      17-7月 -00
# 1076      04003669      17-7月 -00
# 1077      04003669      17-7月 -00
# 1078      04003669      17-7月 -00
# 1079      04003669      17-7月 -00
# 1080      04003669      17-7月 -00
# 1291      04004656      14-5月 -00
# 1292      04004656      14-5月 -00
# 1293      04004656      14-5月 -00
# 1294      04004656      14-5月 -00
# 1295      04004656      14-5月 -00
# 1296      04004656      14-5月 -00
# 1297      04004656      14-5月 -00
# 1328      08000379      22-2月 -00
# 1329      08000379      22-2月 -00
# 1330      08000379      22-2月 -00
# 1331      08000379      22-2月 -00
# 1358      04008472      30-6月 -00
# ...

# %%
PAT_NO_SAME_1 = DATA_count.drop_duplicates(['PATIENT_ID'],'last')
PAT_NO_SAME_1
# Out:
#         PATIENT_ID DIAGNOSIS_DATE
# 288359    04393224      18-10月-10
# 293990    04169768      11-10月-10
# 296214    06000055      24-11月-08
# 297719    04199935      01-11月-08
# 298813    04179802      06-12月-08
# 298964    04113345      13-12月-08
# 299023    04045443      04-3月 -09
# 299038    04214971      06-3月 -09
# 299792    04265801      30-10月-08
# 302921    04106885      18-2月 -09
# 307040    04292138      09-6月 -09
# 314187    04087648      02-2月 -10
# 314280    04327365      04-11月-09
# 316879    04342317      23-2月 -10
# 317543    04337730      15-1月 -10
# 319195    04067797      02-3月 -10
# 320717    04296057      10-3月 -10
# 321168    04318940      24-9月 -09
# 322713    04311124      19-10月-09
# 324104    04081177      04-11月-09
# 330989    04162186      10-3月 -08
# 331890    04251378      03-7月 -08
# 334047    04225724      17-6月 -08
# 339861    04066479      06-2月 -09
# 340164    04167191      07-4月 -09
# 340956    04277671      07-3月 -09
# ...

# %%
PAT_NO_SAME_1.to_csv("F:/data/output/心5_就诊日期_信息.tsv")

# %%
# 经检验 需要全部字段 此处重做 表9.7 诊断分类记录 DIAGNOSTIC_CATEGORY 预处理 得到病人ID和疾病ID
DIAGNOSTIC_CATEGORY = pd.read_csv('F:/data/input/诊断分类记录_全.tsv', sep='\t')  
print(DIAGNOSTIC_CATEGORY)
# Out:
#         PATIENT_ID  VISIT_ID DIAGNOSIS_TYPE  DIAGNOSIS_NO    DIAGNOSIS_CODE  \
# 0         04003500         2              2             1           261  01
# 1         04003500         2              3             1           307.101
# 2         04003500         2              3             2           273.801
# 3         04003500         2              3             3           280  01
# 4         04010720         1              5             1           799.402
# 5         04010720         1              6             1           567.905
# 6         04007153         1              1             1  070.901+573.106*
# 7         04007153         1              2             1  070.901+573.106*
# 8         04007153         1              3             1           155.201
# 9         04017543         1              1             1           162.901
# 10        04017543         1              2             1           793.101
# ...

# %%
#step6 I50.903(心功能Ⅲ级)
alist=['I50.903']
DIAGNOSTIC_CATEGORY[DIAGNOSTIC_CATEGORY['DIAGNOSIS_CODE'].isin(alist)]
# Out:
#         PATIENT_ID  VISIT_ID DIAGNOSIS_TYPE  DIAGNOSIS_NO DIAGNOSIS_CODE  \
# 241510    04064208        17              2             3        I50.903
# 241516    04064208        17              3             3        I50.903
# 241722    04457799         1              A             2        I50.903
# 241846    04230295         1              A             4        I50.903
# 241961    04115848         7              A             3        I50.903
# 242292    04327447         2              A             2        I50.903
# 243026    06000110         2              A             2        I50.903
# 243656    04113358         4              A             2        I50.903
# 244011    04139790         2              2             3        I50.903
# 244016    04139790         2              3             3        I50.903
# 244296    06003511        12              A             4        I50.903
# 245451    04038438         1              A             3        I50.903
# ...

# %%
#重定义
test = DIAGNOSTIC_CATEGORY[DIAGNOSTIC_CATEGORY['DIAGNOSIS_CODE'].isin(alist)]
print(test)
# Out:
#         PATIENT_ID  VISIT_ID DIAGNOSIS_TYPE  DIAGNOSIS_NO DIAGNOSIS_CODE  \
# 241510    04064208        17              2             3        I50.903
# 241516    04064208        17              3             3        I50.903
# 241722    04457799         1              A             2        I50.903
# 241846    04230295         1              A             4        I50.903
# 241961    04115848         7              A             3        I50.903
# 242292    04327447         2              A             2        I50.903
# 243026    06000110         2              A             2        I50.903
# 243656    04113358         4              A             2        I50.903
# 244011    04139790         2              2             3        I50.903
# 244016    04139790         2              3             3        I50.903
# 244296    06003511        12              A             4        I50.903
# 245451    04038438         1              A             3        I50.903
# ...

# %%
#筛选出频率第一疾病的实际患病人数 9130人
DF = test['PATIENT_ID'].unique()   
#转格式
SS = Series(DF)
SS
# Out:
# 0      04064208
# 1      04457799
# 2      04230295
# 3      04115848
# 4      04327447
# 5      06000110
# 6      04113358
# 7      04139790
# 8      06003511
# 9      04038438
# 10     04261226
# 11     04448266
# 12     04182613
# 13     04007436
# 14     04096677
# 15     04067913
# 16     04246896
# 17     04043236
# 18     04459768
# 19     04008873
# 20     04080559
# 21     04270311
# 22     04131572
# 23     04184803
# 24     04076417
# 25     04270289
# 26     04250691
# 27     04058472
# 28     04053298
# 29     04027887
#          ...
# 869    04470899
# 870    04861605
# 871    04856345
# 872    04875765
# 873    04874406
# 874    04039109
# 875    02003423
# 876    04995974
# 877    04978863
# 878    04967025
# 879    04044839
# 880    04190597
# 881    04992536
# 882    04996103
# 883    04922589
# 884    04428030
# 885    04735829
# 886    04973034
# 887    04067470
# 888    04901388
# 889    04124723
# 890    04995335
# 891    04139503
# 892    04105681
# ...

# %%
#病人ID
DF
# Out:
# array(['04064208', '04457799', '04230295', '04115848', '04327447',
#        '06000110', '04113358', '04139790', '06003511', '04038438',
#        '04261226', '04448266', '04182613', '04007436', '04096677',
#        '04067913', '04246896', '04043236', '04459768', '04008873',
#        '04080559', '04270311', '04131572', '04184803', '04076417',
#        '04270289', '04250691', '04058472', '04053298', '04027887',
#        '04271316', '04092287', '04255804', '08000333', '08000092',
#        '04079346', '04203223', '04270955', '04236803', '04261440',
#        '08000598', '04189207', '04017129', '04189463', '04285667',
#        '04002377', '04193523', '04005101', '04118138', '04241198',
#        '04321405', '04322229', '04298406', '04057583', '04183497',
#        '04034755', '04376143', '04309988', '04358905', '04122451',
#        '06000807', '04003497', '04250061', '04285152', '04333009',
#        '04061469', '04027711', '04023499', '08000325', '04150940',
# ...

# %%
# 9.4 表 诊断记录  预处理后
PAT_DATA = pd.read_csv('F:/data/input/就诊日期.tsv', sep='\t')
PAT_DATA
# Out:
#         PATIENT_ID DIAGNOSIS_DATE
# 0         08000598      07-6月 -00
# 1         08000598      17-6月 -00
# 2         08000279      10-6月 -00
# 3         08000279      10-6月 -00
# 4         08000279      10-6月 -00
# 5         08000279      10-6月 -00
# 6         08000279      10-6月 -00
# 7         08000279      10-6月 -00
# 8         04012492      25-7月 -00
# 9         06001257      29-6月 -00
# 10        06001257      29-6月 -00
# 11        06001257      29-6月 -00
# 12        06001257      29-6月 -00
# 13        06001257      29-6月 -00
# 14        06001257      29-6月 -00
# 15        06001257      29-6月 -00
# 16        04012492      25-7月 -00
# 17        04004716      25-7月 -00
# 18        07002615      04-6月 -00
# 19        07002615      04-6月 -00
# 20        07002615      04-6月 -00
# 21        04005889      16-6月 -00
# 22        04010327      30-6月 -00
# 23        04010327      30-6月 -00
# 24        04010327      30-6月 -00
# 25        04010327      30-6月 -00
# ...

# %%
DATA_count = PAT_DATA[PAT_DATA['PATIENT_ID'].isin(DF)]
DATA_count
# Out:
#         PATIENT_ID DIAGNOSIS_DATE
# 0         08000598      07-6月 -00
# 1         08000598      17-6月 -00
# 139       04008472      30-6月 -00
# 140       04008472      30-6月 -00
# 157       06000797      30-4月 -00
# 158       06000797      30-4月 -00
# 159       06000797      30-4月 -00
# 160       06000797      30-4月 -00
# 161       06000797      30-4月 -00
# 162       06000797      30-4月 -00
# 299       08000550      11-5月 -00
# 300       08000550      11-5月 -00
# 301       08000550      11-5月 -00
# 316       04005269      05-6月 -00
# 317       04005269      05-6月 -00
# 318       04005269      05-6月 -00
# 319       04005269      05-6月 -00
# 320       04005269      05-6月 -00
# 388       04032188      24-5月 -00
# 389       04032188      24-5月 -00
# 390       04032188      24-5月 -00
# 391       04032188      24-5月 -00
# 392       04032188      24-5月 -00
# 452       04008472      22-5月 -00
# 454       04008472      22-5月 -00
# 459       04008472      22-5月 -00
# ...

# %%
PAT_NO_SAME_1 = DATA_count.drop_duplicates(['PATIENT_ID'],'last')
PAT_NO_SAME_1
# Out:
#         PATIENT_ID DIAGNOSIS_DATE
# 291113    04329259      02-11月-10
# 291625    04243940      23-9月 -10
# 292682    04392998      16-10月-10
# 297144    04270289      23-12月-08
# 304575    04000485      27-7月 -09
# 304852    04080779      26-5月 -09
# 306186    04309135      18-7月 -09
# 308621    04271316      30-12月-08
# 314187    04087648      02-2月 -10
# 320935    04331087      04-12月-09
# 321857    04331797      27-11月-09
# 322163    04109258      03-11月-09
# 322423    04158828      10-12月-09
# 326401    04321405      06-10月-09
# 328526    04322229      08-10月-09
# 339252    04280294      18-3月 -09
# 339648    08000607      26-3月 -09
# 345024    04294408      04-5月 -09
# 345152    04270955      01-2月 -09
# 345298    04276723      23-2月 -09
# 345512    08000452      12-5月 -09
# 345685    04275513      12-2月 -09
# 348333    04322532      01-6月 -10
# 348471    04358165      18-5月 -10
# 351986    04355408      04-5月 -10
# 352392    04309988      15-5月 -10
# ...

# %%
PAT_NO_SAME_1.to_csv("F:/data/output/心6_就诊日期_信息.tsv")
